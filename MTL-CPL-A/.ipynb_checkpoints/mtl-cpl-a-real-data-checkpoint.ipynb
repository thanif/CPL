# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(1)
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.compat.v1.Session(config=config)
import matplotlib.pyplot as plt
import PIL.Image as Image
import math
import numpy as np
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
import json
from tensorflow.keras.losses import mse
import os
import glob
import random
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.inception_v3 import InceptionV3
import datetime
from tensorflow.keras.layers import Dense, Input, concatenate, Conv2D, MaxPooling2D, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard
# %matplotlib inline
# Out:
# 2022-01-06 17:27:52.562219: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /home/talha/anaconda3/envs/thesis-exp/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2022-01-06 17:27:53.628744: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-06 17:27:53.654812: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2799925000 Hz
# 2022-01-06 17:27:53.655812: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558c6f9f3f30 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-06 17:27:53.655867: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-01-06 17:27:53.659283: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-01-06 17:27:53.743637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:27:53.744091: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558c6fa1f2c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-01-06 17:27:53.744108: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1050 Ti, Compute Capability 6.1
# 2022-01-06 17:27:53.744335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:27:53.744612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-01-06 17:27:53.744654: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-06 17:27:53.746182: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-01-06 17:27:53.747499: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-01-06 17:27:53.747794: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-01-06 17:27:53.749120: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-01-06 17:27:53.749937: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-01-06 17:27:53.752825: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-01-06 17:27:53.752991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:27:53.753432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:27:53.753666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-01-06 17:27:53.753696: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-06 17:27:54.142119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-06 17:27:54.142181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-01-06 17:27:54.142189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-01-06 17:27:54.142474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:27:54.142913: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:27:54.143183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2636 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)

# %%
def add_layer(tensor):
    return tensor[0] + tensor[1]

def mul_layer(tensor):
    return tensor[0] * tensor[1]

def div_layer(tensor):
    return tensor[0] / tensor[1]

def sub_layer(tensor):
    return tensor[0] - tensor[1]

def neg_layer(tensor):
    return -tensor

def cos_layer(tensor):
    return tf.math.cos(tensor)

def sin_layer(tensor):
    return tf.math.sin(tensor)

# %% [markdown]
# # Model

# %%
# feature extraction from left image
left_img = Input(shape = (112,112,3), name="left_image")

# feature extraction from right image
right_img = Input(shape = (112,112,3), name="right_image")

left_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=left_img, input_shape=(112,112,3))
left_phi_features = left_phi_model.output
left_flat = Flatten(name='left-phi-flattened')(left_phi_features)

right_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=right_img, input_shape=(112,112,3))
right_phi_features = right_phi_model.output
right_flat = Flatten(name='right-phi-flattened')(right_phi_features)

concat = concatenate([left_flat, right_flat])

# fx
dense_1 = Dense(120, activation = 'relu')(concat)
dense_2 = Dense(84, activation = 'relu')(dense_1)
pred_fx = Dense(1, name='fx')(dense_2)

# fy
dense_3 = Dense(120, activation = 'relu')(concat)
dense_4 = Dense(84, activation = 'relu')(dense_3)
pred_fy = Dense(1, name='fy')(dense_4)

# u0
dense_5 = Dense(120, activation = 'relu')(concat)
dense_6 = Dense(84, activation = 'relu')(dense_5)
pred_u0 = Dense(1, name='u0')(dense_6)

# v0
dense_7 = Dense(120, activation = 'relu')(concat)
dense_8 = Dense(84, activation = 'relu')(dense_7)
pred_v0 = Dense(1, name='v0')(dense_8)

# baseline
dense_9 = Dense(120, activation = 'relu')(concat)
dense_10 = Dense(84, activation = 'relu')(dense_9)
pred_baseline = Dense(1, name='baseline')(dense_10)

# tx
dense_11 = Dense(120, activation = 'relu')(concat)
dense_12 = Dense(84, activation = 'relu')(dense_11)
pred_x = Dense(1, name='x')(dense_12)

# ty
dense_13 = Dense(120, activation = 'relu')(concat)
dense_14 = Dense(84, activation = 'relu')(dense_13)
pred_y = Dense(1, name='y')(dense_14)

# tz
dense_15 = Dense(120, activation = 'relu')(concat)
dense_16 = Dense(84, activation = 'relu')(dense_15)
pred_z = Dense(1, name='z')(dense_16)

# pitch
dense_17 = Dense(120, activation = 'relu')(concat)
dense_18 = Dense(84, activation = 'relu')(dense_17)
pred_pitch = Dense(1, name='pitch')(dense_18)

# u
dense_19 = Dense(120, activation = 'relu')(concat)
dense_20 = Dense(84, activation = 'relu')(dense_19)
pred_u = Dense(1, name='u')(dense_20)

# v
dense_21 = Dense(120, activation = 'relu')(concat)
dense_22 = Dense(84, activation = 'relu')(dense_21)
pred_v = Dense(1, name='v')(dense_22)

# disparity
dense_23 = Dense(120, activation = 'relu')(concat)
dense_24 = Dense(84, activation = 'relu')(dense_23)
pred_disparity = Dense(1, name='disparity')(dense_24)

# w_xcam
dense_25 = Dense(120, activation = 'relu')(concat)
dense_26 = Dense(84, activation = 'relu')(dense_25)
w_xcam = Dense(1, name='w_xcam', activation = 'sigmoid')(dense_26)

# w_ycam
dense_27 = Dense(120, activation = 'relu')(concat)
dense_28 = Dense(84, activation = 'relu')(dense_27)
w_ycam = Dense(1, name='w_ycam', activation = 'sigmoid')(dense_28)

# w_zcam
dense_29 = Dense(120, activation = 'relu')(concat)
dense_30 = Dense(84, activation = 'relu')(dense_29)
w_zcam = Dense(1, name='w_zcam', activation = 'sigmoid')(dense_30)

# w_xworld
dense_31 = Dense(120, activation = 'relu')(concat)
dense_32 = Dense(84, activation = 'relu')(dense_31)
w_xworld = Dense(1, name='w_xworld', activation = 'sigmoid')(dense_32)

# w_yworld
dense_33 = Dense(120, activation = 'relu')(concat)
dense_34 = Dense(84, activation = 'relu')(dense_33)
w_yworld = Dense(1, name='w_yworld', activation = 'sigmoid')(dense_34)

# w_zworld
dense_35 = Dense(120, activation = 'relu')(concat)
dense_36 = Dense(84, activation = 'relu')(dense_35)
w_zworld = Dense(1, name='w_zworld', activation = 'sigmoid')(dense_36)


# xCam = (self.intrinsic.fx * self.extrinsic.baseline) / disparity
mul_1 = Lambda(mul_layer)([pred_fx, pred_baseline])
xCam = Lambda(div_layer)([mul_1, pred_disparity])
xCam = Lambda(mul_layer, name='xCam')([xCam, w_xcam])

# yCam = - (xCam / self.intrinsic.fx) * (u - self.intrinsic.u0)
div_1 = Lambda(div_layer)([xCam, pred_fx])
sub_1 = Lambda(sub_layer)([pred_u, pred_u0])
yCam = Lambda(mul_layer)([Lambda(neg_layer)(div_1), sub_1])
yCam = Lambda(mul_layer, name='yCam')([yCam, w_ycam])

# zCam = (xCam / self.intrinsic.fy) * (self.intrinsic.v0 - v)
div_2 = Lambda(div_layer)([xCam, pred_fy])
sub_2 = Lambda(sub_layer)([pred_v0, pred_v])
zCam = Lambda(mul_layer)([div_2, sub_2])
zCam = Lambda(mul_layer, name='zCam')([zCam, w_zcam])

# Y = yCam + self.extrinsic.y
pred_yWorld = Lambda(add_layer)([yCam, pred_y])
pred_yWorld = Lambda(mul_layer, name='yWorld')([pred_yWorld, w_yworld])

# X = xCam * math.cos(self.extrinsic.pitch) + zCam * math.sin(self.extrinsic.pitch) + self.extrinsic.x
mul_2 = Lambda(mul_layer)([xCam, Lambda(cos_layer)(pred_pitch)])
mul_3 = Lambda(mul_layer)([zCam, Lambda(sin_layer)(pred_pitch)])
add_1 = Lambda(add_layer)([mul_2, mul_3])
pred_xWorld = Lambda(add_layer)([add_1, pred_x])
pred_xWorld = Lambda(mul_layer, name='xWorld')([pred_xWorld, w_xworld])

# Z = - xCam * math.sin(self.extrinsic.pitch) + zCam * math.cos(self.extrinsic.pitch) + self.extrinsic.z
mul_4 = Lambda(mul_layer)([Lambda(neg_layer)(xCam), Lambda(sin_layer)(pred_pitch)])
mul_5 = Lambda(mul_layer)([zCam, Lambda(cos_layer)(pred_pitch)])
add_2 = Lambda(add_layer)([mul_4, mul_5])
pred_zWorld = Lambda(add_layer)([add_2, pred_z])
pred_zWorld = Lambda(mul_layer, name='zWorld')([pred_zWorld, w_zworld])

# create model
model = Model(inputs=[left_img, right_img], outputs=[pred_fx, pred_fy, pred_u0, pred_v0, pred_baseline, pred_disparity, pred_x, pred_y, pred_z, pred_pitch, pred_xWorld,pred_yWorld,pred_zWorld])

# set output types
target1 = tf.placeholder(dtype='float32', shape=(1,1)) 
target2 = tf.placeholder(dtype='float32', shape=(1,1))
target3 = tf.placeholder(dtype='float32', shape=(1,1))
target4 = tf.placeholder(dtype='float32', shape=(1,1)) 
target5 = tf.placeholder(dtype='float32', shape=(1,1))
target6 = tf.placeholder(dtype='float32', shape=(1,1))
target7 = tf.placeholder(dtype='float32', shape=(1,1)) 
target8 = tf.placeholder(dtype='float32', shape=(1,1))
target9 = tf.placeholder(dtype='float32', shape=(1,1))
target10 = tf.placeholder(dtype='float32', shape=(1,1)) 
target11 = tf.placeholder(dtype='float32', shape=(1,1))
target12 = tf.placeholder(dtype='float32', shape=(1,1))
target13 = tf.placeholder(dtype='float32', shape=(1,1))

# get model summary
model.summary()

learning_rate = 0.001

# compile model
model.compile(loss="mae", target_tensors=[target1, target2, target3, target4, target5, target6, target7, target8, target9, target10, target11, target12, target13],optimizer=optimizers.Adam(lr=learning_rate))
#plot_model(model, to_file='model.png')
# Out:
# 2022-01-06 17:28:04.496351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.496633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-01-06 17:28:04.496663: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-06 17:28:04.496688: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-01-06 17:28:04.496700: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-01-06 17:28:04.496712: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-01-06 17:28:04.496723: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-01-06 17:28:04.496733: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-01-06 17:28:04.496745: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-01-06 17:28:04.496798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.497007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.497179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-01-06 17:28:04.497768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.498162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-01-06 17:28:04.498206: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-06 17:28:04.498243: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-01-06 17:28:04.498257: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-01-06 17:28:04.498269: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-01-06 17:28:04.498281: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-01-06 17:28:04.498292: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-01-06 17:28:04.498304: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-01-06 17:28:04.498422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.498748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.498966: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-01-06 17:28:04.498992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-06 17:28:04.499002: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-01-06 17:28:04.499011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-01-06 17:28:04.499089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.499328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 17:28:04.499535: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2636 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_image (InputLayer)         [(None, 112, 112, 3) 0
# __________________________________________________________________________________________________
# right_image (InputLayer)        [(None, 112, 112, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 55, 55, 32)   864         left_image[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 55, 55, 32)   864         right_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 55, 55, 32)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 55, 55, 32)   96          conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 55, 55, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 55, 55, 32)   0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 53, 53, 32)   9216        activation[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 53, 53, 32)   9216        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 53, 53, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 53, 53, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 53, 53, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 53, 53, 32)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 53, 53, 64)   18432       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 53, 53, 64)   18432       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 53, 53, 64)   192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 53, 53, 64)   192         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 53, 53, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 53, 53, 64)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 26, 26, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 26, 26, 64)   0           activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 26, 26, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 26, 26, 80)   5120        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 26, 26, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 26, 26, 80)   240         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 26, 26, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 26, 26, 80)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 24, 24, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 24, 24, 192)  138240      activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 24, 24, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 24, 24, 192)  576         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 24, 24, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 24, 24, 192)  0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 11, 11, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 11, 11, 192)  0           activation_98[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 11, 11, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 11, 11, 64)   12288       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 11, 11, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 11, 11, 64)   192         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 11, 11, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 11, 11, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 11, 11, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 11, 11, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 11, 11, 48)   9216        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 11, 11, 96)   55296       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 11, 11, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 11, 11, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 11, 11, 48)   144         conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 11, 11, 96)   288         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 11, 11, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 11, 11, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 11, 11, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 11, 11, 48)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 11, 11, 96)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 11, 11, 192)  0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 11, 11, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 11, 11, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 11, 11, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 11, 11, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 11, 11, 64)   12288       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 11, 11, 64)   76800       activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 11, 11, 96)   82944       activation_103[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 11, 11, 32)   6144        average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 11, 11, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 11, 11, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 11, 11, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 11, 11, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 11, 11, 64)   192         conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 11, 11, 64)   192         conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 11, 11, 96)   288         conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 11, 11, 32)   96          conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 11, 11, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 11, 11, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 11, 11, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 11, 11, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 11, 11, 64)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 11, 11, 64)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 11, 11, 96)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 11, 11, 32)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 11, 11, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 11, 11, 256)  0           activation_99[0][0]
#                                                                  activation_101[0][0]
#                                                                  activation_104[0][0]
#                                                                  activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 11, 11, 64)   16384       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 11, 11, 64)   16384       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 11, 11, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 11, 11, 64)   192         conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 11, 11, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 11, 11, 64)   0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 11, 11, 48)   12288       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 11, 11, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 11, 11, 48)   12288       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 11, 11, 96)   55296       activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 11, 11, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 11, 11, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 11, 11, 48)   144         conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 11, 11, 96)   288         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 11, 11, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 11, 11, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 11, 11, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 11, 11, 48)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 11, 11, 96)   0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 11, 11, 256)  0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 11, 11, 64)   16384       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 11, 11, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 11, 11, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 11, 11, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 11, 11, 64)   16384       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 11, 11, 64)   76800       activation_107[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 11, 11, 96)   82944       activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 11, 11, 64)   16384       average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 11, 11, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 11, 11, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 11, 11, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 11, 11, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 11, 11, 64)   192         conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 11, 11, 64)   192         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 11, 11, 96)   288         conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 11, 11, 64)   192         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 11, 11, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 11, 11, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 11, 11, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 11, 11, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 11, 11, 64)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 11, 11, 64)   0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 11, 11, 96)   0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 11, 11, 64)   0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 11, 11, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 11, 11, 288)  0           activation_106[0][0]
#                                                                  activation_108[0][0]
#                                                                  activation_111[0][0]
#                                                                  activation_112[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 11, 11, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 11, 11, 64)   18432       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 11, 11, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 11, 11, 64)   192         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 11, 11, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 11, 11, 64)   0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 11, 11, 48)   13824       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 11, 11, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 11, 11, 48)   13824       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 11, 11, 96)   55296       activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 11, 11, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 11, 11, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 11, 11, 48)   144         conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 11, 11, 96)   288         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 11, 11, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 11, 11, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 11, 11, 288)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 11, 11, 48)   0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 11, 11, 96)   0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 11, 11, 288)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 11, 11, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 11, 11, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 11, 11, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 11, 11, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 11, 11, 64)   18432       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 11, 11, 64)   76800       activation_114[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 11, 11, 96)   82944       activation_117[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 11, 11, 64)   18432       average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 11, 11, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 11, 11, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 11, 11, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 11, 11, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 11, 11, 64)   192         conv2d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 11, 11, 64)   192         conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 11, 11, 96)   288         conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 11, 11, 64)   192         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 11, 11, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 11, 11, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 11, 11, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 11, 11, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 11, 11, 64)   0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 11, 11, 64)   0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 11, 11, 96)   0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 11, 11, 64)   0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 11, 11, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 11, 11, 288)  0           activation_113[0][0]
#                                                                  activation_115[0][0]
#                                                                  activation_118[0][0]
#                                                                  activation_119[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 11, 11, 64)   18432       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 11, 11, 64)   18432       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 11, 11, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 11, 11, 64)   192         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 11, 11, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 11, 11, 64)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 11, 11, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 11, 11, 96)   55296       activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 11, 11, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 11, 11, 96)   288         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 11, 11, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 11, 11, 96)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 5, 5, 384)    995328      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 5, 5, 96)     82944       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 5, 5, 384)    995328      concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 5, 5, 96)     82944       activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 5, 5, 384)    1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 5, 5, 96)     288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 5, 5, 384)    1152        conv2d_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 5, 5, 96)     288         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 5, 5, 384)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 5, 5, 96)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 5, 288)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 5, 5, 384)    0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 5, 5, 96)     0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 5, 5, 288)    0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 5, 5, 768)    0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 5, 5, 768)    0           activation_120[0][0]
#                                                                  activation_123[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 5, 5, 128)    98304       concatenate_3[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 84)           10164       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 84)           10164       dense_6[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           lambda[0][0]
#                                                                  disparity[0][0]
# __________________________________________________________________________________________________
# w_xcam (Dense)                  (None, 1)            85          dense_25[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 84)           10164       dense_20[0][0]
# __________________________________________________________________________________________________
# fy (Dense)                      (None, 1)            85          dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# v0 (Dense)                      (None, 1)            85          dense_7[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# xCam (Lambda)                   (None, 1)            0           lambda_1[0][0]
#                                                                  w_xcam[0][0]
# __________________________________________________________________________________________________
# v (Dense)                       (None, 1)            85          dense_21[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 84)           10164       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 84)           10164       dense_16[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1)            0           xCam[0][0]
#                                                                  fy[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1)            0           v0[0][0]
#                                                                  v[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 84)           10164       dense_28[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 84)           10164       dense_18[0][0]
# __________________________________________________________________________________________________
# u0 (Dense)                      (None, 1)            85          dense_5[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 1)            85          dense_17[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1)            0           lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# w_zcam (Dense)                  (None, 1)            85          dense_29[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1)            0           xCam[0][0]
#                                                                  fx[0][0]
# __________________________________________________________________________________________________
# u (Dense)                       (None, 1)            85          dense_19[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 1)            0           pitch[0][0]
# __________________________________________________________________________________________________
# zCam (Lambda)                   (None, 1)            0           lambda_8[0][0]
#                                                                  w_zcam[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 1)            0           pitch[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1)            0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1)            0           u[0][0]
#                                                                  u0[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 84)           10164       dense_26[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 1)            0           xCam[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 1)            0           pitch[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 1)            0           pitch[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 84)           10164       dense_10[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 84)           10164       dense_12[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 84)           10164       dense_14[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1)            0           xCam[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 1)            0           zCam[0][0]
#                                                                  lambda_13[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1)            0           lambda_5[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# w_ycam (Dense)                  (None, 1)            85          dense_27[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 1)            0           lambda_17[0][0]
#                                                                  lambda_18[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 1)            0           zCam[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 120)          1966200     concatenate_30[0][0]
# __________________________________________________________________________________________________
# x (Dense)                       (None, 1)            85          dense_11[0][0]
# __________________________________________________________________________________________________
# y (Dense)                       (None, 1)            85          dense_13[0][0]
# __________________________________________________________________________________________________
# z (Dense)                       (None, 1)            85          dense_15[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 1)            0           lambda_10[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 84)           10164       dense_30[0][0]
# __________________________________________________________________________________________________
# yCam (Lambda)                   (None, 1)            0           lambda_4[0][0]
#                                                                  w_ycam[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 84)           10164       dense_32[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 1)            0           lambda_16[0][0]
#                                                                  lambda_19[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 84)           10164       dense_34[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 1)            0           lambda_14[0][0]
#                                                                  x[0][0]
# __________________________________________________________________________________________________
# w_xworld (Dense)                (None, 1)            85          dense_31[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1)            0           yCam[0][0]
#                                                                  y[0][0]
# __________________________________________________________________________________________________
# w_yworld (Dense)                (None, 1)            85          dense_33[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           lambda_21[0][0]
#                                                                  z[0][0]
# __________________________________________________________________________________________________
# w_zworld (Dense)                (None, 1)            85          dense_35[0][0]
# __________________________________________________________________________________________________
# xWorld (Lambda)                 (None, 1)            0           lambda_15[0][0]
#                                                                  w_xworld[0][0]
# __________________________________________________________________________________________________
# yWorld (Lambda)                 (None, 1)            0           lambda_9[0][0]
#                                                                  w_yworld[0][0]
# __________________________________________________________________________________________________
# zWorld (Lambda)                 (None, 1)            0           lambda_22[0][0]
#                                                                  w_zworld[0][0]
# ==================================================================================================
# Total params: 79,181,650
# Trainable params: 79,112,786
# Non-trainable params: 68,864
# __________________________________________________________________________________________________

# %% [markdown]
# # Get data

# %% [markdown]
# xCam = (self.intrinsic.fx * self.extrinsic.baseline) / disparity
#
# yCam = - (xCam / self.intrinsic.fx) * (u - self.intrinsic.u0)
#
# zCam = (xCam / self.intrinsic.fy) * (self.intrinsic.v0 - v)
#
# yWorld = yCam + self.extrinsic.y
#
# xWorld = xCam * math.cos(self.extrinsic.pitch) + zCam * \
#             math.sin(self.extrinsic.pitch) + self.extrinsic.x
#
# zWorld = - xCam * math.sin(self.extrinsic.pitch) + zCam * \
#             math.cos(self.extrinsic.pitch) + self.extrinsic.z
#
# Focal_length = ImageSizeX /(2 * tan(CameraFOV * π / 360))
#
# Center_X = ImageSizeX / 2
#
# Center_Y = ImageSizeY / 2

# %% [markdown]
# ## Town 1

# %%
data_path = "../../Town2/"

new_size = (112, 112) 

Left_images = []
Right_images = []
Disparity = []
Tx = []
Ty = []
Tz = []
Baseline = []
Pitch = []
Fx = []
Fy = []
U0 = []
V0 = []
X = []
Y = []
Z = []


for folder in os.listdir(data_path):
    
    if "episode" in folder:
    
        episode_data = os.listdir(data_path+folder)
        
        file = open(data_path+folder+"/params.txt", "r")

        i = 0

        for line in file:
    
            if ":" in line:
        
                if i == 0:
        
                    fov = int(line.split(":")[1])
            
                elif i == 1:
            
                    x = int(line.split(":")[1])
            
                elif i == 2:
            
                    y = int(line.split(":")[1])
            
                elif i == 3:
            
                    z = int(line.split(":")[1])
            
                elif i == 4:
            
                    p = int(line.split(":")[1])
            
                elif i == 5:
            
                    yaw = int(line.split(":")[1])
            
                elif i == 6:
            
                    roll = int(line.split(":")[1])
            
            i += 1
        
        
        for fname in episode_data:
        
            if "Left" in fname:
                
                l_im = cv2.imread(data_path+folder+"/"+fname, 0)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1], 0)
                stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
                disparity_map = stereo.compute(l_im, r_im)
                disparity_value = np.mean(disparity_map)
        
                l_im = cv2.imread(data_path+folder+"/"+fname)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1])
        
                Left_images.append(l_im)
                Right_images.append(r_im)
                Disparity.append(disparity_value)
                Tx.append(x)
                Ty.append(y)
                Tz.append(z)
                Baseline.append(x)
                Pitch.append(p)
                focal_length = new_size[0]/(2*np.tan(fov*np.pi/360))
                center_x = new_size[0]/2
                center_y = center_x
                Fx.append(focal_length)
                Fy.append(focal_length)
                U0.append(center_x)
                V0.append(center_y)
                
                xCam = (focal_length * x) / disparity_value
                yCam = - (xCam / focal_length) * (5 - center_x)
                zCam = (xCam / focal_length) * (center_y - 5)

                yWorld = yCam + y
                xWorld = xCam * math.cos(p) + zCam*math.sin(p) + x
                zWorld = - xCam * math.sin(p) + zCam*math.cos(p) + z
        
                X.append(xWorld)
                Y.append(yWorld)
                Z.append(zWorld)

# %% [markdown]
# ## Town 2

# %%
data_path = "../../Town1/"

new_size = (112, 112) 


for folder in os.listdir(data_path):
    
    if "episode" in folder:
    
        episode_data = os.listdir(data_path+folder)
        
        file = open(data_path+folder+"/params.txt", "r")

        i = 0

        for line in file:
    
            if ":" in line:
        
                if i == 0:
        
                    fov = int(line.split(":")[1])
            
                elif i == 1:
            
                    x = int(line.split(":")[1])
            
                elif i == 2:
            
                    y = int(line.split(":")[1])
            
                elif i == 3:
            
                    z = int(line.split(":")[1])
            
                elif i == 4:
            
                    p = int(line.split(":")[1])
            
                elif i == 5:
            
                    yaw = int(line.split(":")[1])
            
                elif i == 6:
            
                    roll = int(line.split(":")[1])
            
            i += 1
        
        
        for fname in episode_data:
        
            if "Left" in fname:
                
                l_im = cv2.imread(data_path+folder+"/"+fname, 0)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1], 0)
                stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
                disparity_map = stereo.compute(l_im, r_im)
                disparity_value = np.mean(disparity_map)
        
                l_im = cv2.imread(data_path+folder+"/"+fname)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1])
        
                Left_images.append(l_im)
                Right_images.append(r_im)
                Disparity.append(disparity_value)
                Tx.append(x)
                Ty.append(y)
                Tz.append(z)
                Baseline.append(x)
                Pitch.append(p)
                focal_length = new_size[0]/(2*np.tan(fov*np.pi/360))
                center_x = new_size[0]/2
                center_y = center_x
                Fx.append(focal_length)
                Fy.append(focal_length)
                U0.append(center_x)
                V0.append(center_y)
                
                xCam = (focal_length * x) / disparity_value
                yCam = - (xCam / focal_length) * (5 - center_x)
                zCam = (xCam / focal_length) * (center_y - 5)

                yWorld = yCam + y
                xWorld = xCam * math.cos(p) + zCam*math.sin(p) + x
                zWorld = - xCam * math.sin(p) + zCam*math.cos(p) + z
        
                X.append(xWorld)
                Y.append(yWorld)
                Z.append(zWorld)

# %%
print ("dataset: ",np.shape(Z))
# Out:
# dataset:  (79320,)

# %%
print ("Training Dataset: ",len(Left_images)*0.7, "Test Dataset: ", len(Left_images)*0.3)
# Out:
# Training Dataset:  55524.0 Test Dataset:  23796.0

# %%
c = list(zip(Left_images, Right_images, Fx, Fy, U0, V0, Baseline, Disparity, Tx, Ty, Tz, Pitch, X, Y, Z))
random.shuffle(c)
Left_images, Right_images, Fx, Fy, U0, V0, Baseline, Disparity, Tx, Ty, Tz, Pitch, X, Y, Z = zip(*c)
Left_images, Right_images, Fx, Fy, U0, V0, Baseline, Disparity, Tx, Ty, Tz, Pitch, X, Y, Z = list(Left_images), list(Right_images), list(Fx), list(Fy), list(U0), list(V0), list(Baseline), list(Disparity), list(Tx), list(Ty), list(Tz), list(Pitch), list(X), list(Y), list(Z)

# %%
np.save("Left_images.npy", Left_images)
np.save("Right_images.npy", Right_images)
np.save("Fx.npy", Fx)
np.save("Fy.npy", Fy)
np.save("U0.npy", U0)
np.save("V0.npy", V0)
np.save("Baseline.npy", Baseline)
np.save("Disparity.npy", Disparity)
np.save("Tx.npy", Tx)
np.save("Ty.npy", Ty)
np.save("Tz.npy", Tz)
np.save("Pitch.npy", Pitch)
np.save("X.npy", X)
np.save("Y.npy", Y)
np.save("Z.npy", Z)

# %%
Left_images = np.load("Left_images.npy")
Right_images = np.load("Right_images.npy")
Fx = np.load("Fx.npy")
Fy = np.load("Fy.npy")
U0 = np.load("U0.npy")
V0 = np.load("V0.npy")
Baseline = np.load("Baseline.npy")
Disparity = np.load("Disparity.npy")
Tx = np.load("Tx.npy")
Ty = np.load("Ty.npy")
Tz = np.load("Tz.npy")
Pitch = np.load("Pitch.npy")
X = np.load("X.npy")
Y = np.load("Y.npy")
Z = np.load("Z.npy")

# %%
import os
from keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

model_name = 'model_multi_class/'
SAVE = "new_logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '/'
# Save
output_folder = SAVE + model_name
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

output_log = output_folder + "Log/"
if not os.path.exists(output_log):
    os.makedirs(output_log)

output_weight = output_folder + "Best/"
if not os.path.exists(output_weight):
    os.makedirs(output_weight)


input_shape = (112, 112, 3)

tensorboard = TensorBoard(log_dir=output_log)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto', restore_best_weights=True)

csv_logger = CSVLogger('training.log')

checkpointer = CustomModelCheckpoint(
    model_for_saving=model,
    filepath=output_weight + "weights_{epoch:02d}_{val_loss:.2f}.h5",
    save_best_only=True,
    monitor='val_loss',
    save_weights_only=True
)

history = model.fit(
    x=[Left_images[:int(len(Left_images)*0.7)], Right_images[:int(len(Left_images)*0.7)]],
    y=[Fx[:int(len(Left_images)*0.7)], Fy[:int(len(Left_images)*0.7)], U0[:int(len(Left_images)*0.7)], V0[:int(len(Left_images)*0.7)], Baseline[:int(len(Left_images)*0.7)], Disparity[:int(len(Left_images)*0.7)], Tx[:int(len(Left_images)*0.7)], Ty[:int(len(Left_images)*0.7)], Tz[:int(len(Left_images)*0.7)], Pitch[:int(len(Left_images)*0.7)], X[:int(len(Left_images)*0.7)], Y[:int(len(Left_images)*0.7)], Z[:int(len(Left_images)*0.7)]],
    batch_size=16,
    epochs=200,
    verbose=1,
    shuffle=True,
    initial_epoch=0,
    validation_data=([Left_images[int(len(Left_images)*0.7):], Right_images[int(len(Left_images)*0.7):]], [Fx[int(len(Left_images)*0.7):], Fy[int(len(Left_images)*0.7):], U0[int(len(Left_images)*0.7):], V0[int(len(Left_images)*0.7):], Baseline[int(len(Left_images)*0.7):], Disparity[int(len(Left_images)*0.7):], Tx[int(len(Left_images)*0.7):], Ty[int(len(Left_images)*0.7):], Tz[int(len(Left_images)*0.7):], Pitch[int(len(Left_images)*0.7):], X[int(len(Left_images)*0.7):], Y[int(len(Left_images)*0.7):], Z[int(len(Left_images)*0.7):]]),
    callbacks=[tensorboard, checkpointer, early_stopping, csv_logger]
)
# Out:
# Train on 55524 samples, validate on 23796 samples
# W0126 19:56:56.191434 140599983638336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0126 19:56:56.192945 140599983638336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/200
# 55524/55524 [==============================] - 883s 16ms/step - loss: 206.8030 - fx_loss: 33.3104 - fy_loss: 32.9310 - u0_loss: 2.5572 - v0_loss: 2.2826 - baseline_loss: 2.6741 - disparity_loss: 4.6279 - x_loss: 1.5002 - y_loss: 1.3301 - z_loss: 1.2786 - pitch_loss: 37.8309 - xWorld_loss: 31.2818 - yWorld_loss: 11.8812 - zWorld_loss: 43.3171 - val_loss: 393.8197 - val_fx_loss: 37.3888 - val_fy_loss: 56.7680 - val_u0_loss: 44.9530 - val_v0_loss: 45.0649 - val_baseline_loss: 2.7923 - val_disparity_loss: 11.6110 - val_x_loss: 2.7586 - val_y_loss: 1.1073 - val_z_loss: 1.4312 - val_pitch_loss: 105.5646 - val_xWorld_loss: 31.3370 - val_yWorld_loss: 9.9819 - val_zWorld_loss: 43.0614
# Epoch 2/200
# 55524/55524 [==============================] - 847s 15ms/step - loss: 150.9564 - fx_loss: 17.1007 - fy_loss: 17.2770 - u0_loss: 0.8289 - v0_loss: 0.9124 - baseline_loss: 2.8712 - disparity_loss: 1.6911 - x_loss: 1.5348 - y_loss: 1.1213 - z_loss: 1.2667 - pitch_loss: 23.8538 - xWorld_loss: 30.1865 - yWorld_loss: 9.7171 - zWorld_loss: 42.5950 - val_loss: 644.4807 - val_fx_loss: 79.4476 - val_fy_loss: 145.3662 - val_u0_loss: 90.1342 - val_v0_loss: 96.5269 - val_baseline_loss: 2.9208 - val_disparity_loss: 9.3882 - val_x_loss: 2.9612 - val_y_loss: 1.0671 - val_z_loss: 1.3656 - val_pitch_loss: 134.0297 - val_xWorld_loss: 30.8216 - val_yWorld_loss: 8.5296 - val_zWorld_loss: 41.9218
# Epoch 3/200
# 55524/55524 [==============================] - 846s 15ms/step - loss: 133.0579 - fx_loss: 12.2357 - fy_loss: 12.3630 - u0_loss: 0.5028 - v0_loss: 0.5827 - baseline_loss: 2.8905 - disparity_loss: 0.6578 - x_loss: 1.4080 - y_loss: 1.0849 - z_loss: 1.3750 - pitch_loss: 19.9479 - xWorld_loss: 29.9410 - yWorld_loss: 7.9028 - zWorld_loss: 42.1658 - val_loss: 559.5056 - val_fx_loss: 77.9266 - val_fy_loss: 182.2693 - val_u0_loss: 64.7596 - val_v0_loss: 67.1311 - val_baseline_loss: 2.8583 - val_disparity_loss: 6.1597 - val_x_loss: 5.1001 - val_y_loss: 1.0225 - val_z_loss: 1.1959 - val_pitch_loss: 68.7748 - val_xWorld_loss: 31.0738 - val_yWorld_loss: 10.1017 - val_zWorld_loss: 41.1320
# Epoch 4/200
# 55524/55524 [==============================] - 847s 15ms/step - loss: 130.4835 - fx_loss: 11.8402 - fy_loss: 11.9377 - u0_loss: 0.4430 - v0_loss: 0.5015 - baseline_loss: 2.8772 - disparity_loss: 0.3542 - x_loss: 1.0977 - y_loss: 1.0078 - z_loss: 1.2530 - pitch_loss: 21.8404 - xWorld_loss: 29.5134 - yWorld_loss: 6.5206 - zWorld_loss: 41.2969 - val_loss: 530.8640 - val_fx_loss: 148.4158 - val_fy_loss: 117.1364 - val_u0_loss: 44.3580 - val_v0_loss: 48.4656 - val_baseline_loss: 2.8835 - val_disparity_loss: 5.7577 - val_x_loss: 2.2158 - val_y_loss: 1.0698 - val_z_loss: 3.6453 - val_pitch_loss: 76.8198 - val_xWorld_loss: 29.7499 - val_yWorld_loss: 7.5171 - val_zWorld_loss: 42.8292
# Epoch 5/200
# 55524/55524 [==============================] - 846s 15ms/step - loss: 156.5006 - fx_loss: 22.4386 - fy_loss: 22.5265 - u0_loss: 0.4469 - v0_loss: 0.4821 - baseline_loss: 2.8691 - disparity_loss: 0.3371 - x_loss: 1.0116 - y_loss: 1.0642 - z_loss: 1.2011 - pitch_loss: 26.3519 - xWorld_loss: 29.5326 - yWorld_loss: 7.6095 - zWorld_loss: 40.6294 - val_loss: 8646.3694 - val_fx_loss: 1233.0537 - val_fy_loss: 1486.8760 - val_u0_loss: 1699.2640 - val_v0_loss: 1458.0590 - val_baseline_loss: 2.8731 - val_disparity_loss: 203.7361 - val_x_loss: 1.6410 - val_y_loss: 1.1124 - val_z_loss: 18.9845 - val_pitch_loss: 2446.3354 - val_xWorld_loss: 29.6359 - val_yWorld_loss: 9.6457 - val_zWorld_loss: 55.1524
# Epoch 6/200
# 55524/55524 [==============================] - 847s 15ms/step - loss: 138.8687 - fx_loss: 17.2482 - fy_loss: 17.2965 - u0_loss: 0.6015 - v0_loss: 0.5903 - baseline_loss: 2.8455 - disparity_loss: 0.3512 - x_loss: 1.0106 - y_loss: 0.9826 - z_loss: 1.1950 - pitch_loss: 21.0258 - xWorld_loss: 29.2543 - yWorld_loss: 6.7832 - zWorld_loss: 39.6841 - val_loss: 2985.3289 - val_fx_loss: 469.3685 - val_fy_loss: 685.6177 - val_u0_loss: 489.8955 - val_v0_loss: 503.6413 - val_baseline_loss: 2.8636 - val_disparity_loss: 41.0573 - val_x_loss: 11.8684 - val_y_loss: 0.9368 - val_z_loss: 1.2064 - val_pitch_loss: 696.0576 - val_xWorld_loss: 36.8161 - val_yWorld_loss: 6.5417 - val_zWorld_loss: 39.4582
# Restoring model weights from the end of the best epoch
# Epoch 00006: early stopping

# %%
import os
from keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session


model.load_weights('weights_01_124.37.h5')



input_shape = (112, 112, 3)


output = model.predict(
    x=[Left_images[int(len(Left_images)*0.7):], Right_images[int(len(Left_images)*0.7):]],
    batch_size=16,
    verbose=1
)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/talha/anaconda3/envs/thesis-exp/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_v1.py:2066: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-01-06 17:38:01.141218: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-01-06 17:38:04.400183: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-01-06 17:38:14.596293: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 962.56MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-01-06 17:38:14.667841: W tensorflow/core/common_runtime/bfc_allocator.cc:312] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2022-01-06 17:38:14.753401: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.12GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-01-06 17:38:15.179085: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.78GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-01-06 17:38:15.200154: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.78GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-01-06 17:38:15.203019: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-01-06 17:40:28.439146: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.72GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-01-06 17:40:28.456095: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.00GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.

# %%
np.shape(output)
# Out:
# (13, 23796, 1)

# %%
th_0 = 0
th_1 = 0
th_2 = 0
th_3 = 0
th_4 = 0
th_5 = 0

percent_correct = []

k = 55524

for i  in range(np.shape(output)[1]):
    
    predicted_fov = 2*np.arctan(112/(2*output[0][i][0]))
    actual_fov = 2*np.arctan(112/(2*Fx[k]))
    
    if abs(predicted_fov - actual_fov) <= 0:
        
        th_0 += 1 
        
    if abs(predicted_fov - actual_fov) <= 1:
        
        th_1 += 1
        
    if abs(predicted_fov - actual_fov) <= 2:
        
        th_2 += 1
        
    if abs(predicted_fov - actual_fov) <= 3:
        
        th_3 += 1
        
    if abs(predicted_fov - actual_fov) <= 4:
        
        th_4 += 1
        
    if abs(predicted_fov - actual_fov) <= 5:
        
        th_5 += 1
        
    k += 1

percent_correct.append(th_0/np.shape(output)[1]*100)
percent_correct.append(th_1/np.shape(output)[1]*100)
percent_correct.append(th_2/np.shape(output)[1]*100)
percent_correct.append(th_3/np.shape(output)[1]*100)
percent_correct.append(th_4/np.shape(output)[1]*100)
percent_correct.append(th_5/np.shape(output)[1]*100)

plt.plot([0,1,2,3,4,5],percent_correct)
plt.xlabel("FOV Error Threshold (degrees)")
plt.ylabel("% Correct")
# Out:
# Text(0, 0.5, '% Correct')

# %%
th_0, th_1, th_2, th_3, th_4, th_5
# Out:
# (0, 23745, 23794, 23796, 23796, 23796)

# %%
th_0/np.shape(output)[1], th_1/np.shape(output)[1], th_2/np.shape(output)[1], th_3/np.shape(output)[1]
# Out:
# (0.0, 0.9978567826525466, 0.9999159522608841, 1.0)

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0



key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[1]):
        
        if key_counter == 0: 
    
            predicted_fx = output[key_counter][j][0]
            actual_fx = Fx[k]
    
            error[i] += abs(predicted_fx - actual_fx)
        
        if key_counter == 1: 
    
            predicted_fy = output[key_counter][j][0]
            actual_fy = Fy[k]
    
            error[i] += abs(predicted_fy - actual_fy)
        
        if key_counter == 2: 
    
            predicted_u0 = output[key_counter][j][0]
            actual_u0 = U0[k]
    
            error[i] += abs(predicted_u0 - actual_u0)
        
        if key_counter == 3: 
    
            predicted_v0 = output[key_counter][j][0]
            actual_v0 = V0[k]
    
            error[i] += abs(predicted_v0 - actual_v0)
        
        if key_counter == 4: 
    
            predicted_baseline = output[key_counter][j][0]
            actual_baseline = Baseline[k]
    
            error[i] += abs(predicted_baseline - actual_baseline)
        
        if key_counter == 5: 
    
            predicted_disparity = output[key_counter][j][0]
            actual_disparity = Disparity[k]
    
            error[i] += abs(predicted_disparity - actual_disparity)
        
        if key_counter == 6: 
    
            predicted_tx = output[key_counter][j][0]
            actual_tx = Tx[k]
    
            error[i] += abs(predicted_tx - actual_tx)
        
        if key_counter == 7: 
    
            predicted_ty = output[key_counter][j][0]
            actual_ty = Ty[k]
    
            error[i] += abs(predicted_ty - actual_ty)
        
        if key_counter == 8: 
    
            predicted_tz = output[key_counter][j][0]
            actual_tz = Tz[k]
    
            error[i] += abs(predicted_tz - actual_tz)
        
        if key_counter == 9: 
    
            predicted_pitch = output[key_counter][j][0]
            actual_pitch = Pitch[k]
    
            error[i] += abs(predicted_pitch - actual_pitch)
        
        if key_counter == 10: 
    
            predicted_x = output[key_counter][j][0]
            actual_x = X[k]
    
            error[i] += abs(predicted_x - actual_x)
        
        if key_counter == 11: 
    
            predicted_y = output[key_counter][j][0]
            actual_y = Y[k]
    
            error[i] += abs(predicted_y - actual_y)
        
        if key_counter == 12: 
    
            predicted_z = output[key_counter][j][0]
            actual_z = Z[k]
    
            error[i] += abs(predicted_z - actual_z)
        
        k += 1
    
    
    error[i] /= np.shape(output)[1]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 4.790476796624856, 'fy': 4.223400727491196, 'u0': 4.1264191574761, 'v0': 3.970785685238026, 'baseline': 0.6582014018005634, 'disparity': 0.25050594944070115, 'x': 2.418684944814795, 'y': 0.6199106202118135, 'z': 2.418745852527167, 'pitch': 5.693148333879254, 'xworld': 28.689357298387108, 'yworld': 25.171792762801815, 'zworld': 41.33466969195934}

# %%
max(output[0])[0]
# Out:
# 1124.5992

# %% [markdown]
# # Normalization

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0



key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[1]):
        
        if key_counter == 0: 
    
            predicted_fx = output[key_counter][j][0]
            actual_fx = Fx[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Fx[int(len(Fx)*0.7):])
            min_actual = min(Fx[int(len(Fx)*0.7):])
            
            predicted_fx = (predicted_fx - min_output)/float((max_output - min_output)+0.01)
            
            actual_fx = (actual_fx - min_actual)/float((max_actual - min_actual)+0.01)
    
            error[i] += abs(predicted_fx - actual_fx)
        
        if key_counter == 1: 
    
            predicted_fy = output[key_counter][j][0]
            actual_fy = Fy[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Fy[int(len(Fx)*0.7):])
            min_actual = min(Fy[int(len(Fx)*0.7):])
            
            predicted_fy = (predicted_fy - min_output)/float((max_output - min_output)+0.01)
            
            actual_fy = (actual_fy - min_actual)/float((max_actual - min_actual)+0.01)
    
            error[i] += abs(predicted_fy - actual_fy)
        
        if key_counter == 2: 
    
            predicted_u0 = output[key_counter][j][0]
            actual_u0 = U0[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(U0[int(len(Fx)*0.7):])
            min_actual = min(U0[int(len(Fx)*0.7):])
            
            predicted_u0 = (predicted_u0 - min_output)/float((max_output - min_output)+0.01)
            
            actual_u0 = (actual_u0 - min_actual)/float((max_actual - min_actual)+0.01)
    
            error[i] += abs(predicted_u0 - actual_u0)
        
        if key_counter == 3: 
    
            predicted_v0 = output[key_counter][j][0]
            actual_v0 = V0[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(V0[int(len(Fx)*0.7):])
            min_actual = min(V0[int(len(Fx)*0.7):])
            
            predicted_v0 = (predicted_v0 - min_output)/float((max_output - min_output)+0.01)
            
            actual_v0 = (actual_v0 - min_actual)/float((max_actual - min_actual)+0.01)
    
            error[i] += abs(predicted_v0 - actual_v0)
        
        if key_counter == 4: 
    
            predicted_baseline = output[key_counter][j][0]
            actual_baseline = Baseline[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Baseline[int(len(Fx)*0.7):])
            min_actual = min(Baseline[int(len(Fx)*0.7):])
            
            predicted_baseline = (predicted_baseline - min_output)/float((max_output - min_output)+0.01)
            
            actual_baseline = (actual_baseline - min_actual)/float((max_actual - min_actual)+0.01)
    
            error[i] += abs(predicted_baseline - actual_baseline)
        
        if key_counter == 5: 
    
            predicted_disparity = output[key_counter][j][0]
            actual_disparity = Disparity[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Disparity[int(len(Fx)*0.7):])
            min_actual = min(Disparity[int(len(Fx)*0.7):])
            
            predicted_disparity = (predicted_disparity - min_output)/float((max_output - min_output)+0.01)
            
            actual_disparity = (actual_disparity - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_disparity - actual_disparity)
        
        if key_counter == 6: 
    
            predicted_tx = output[key_counter][j][0]
            actual_tx = Tx[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Tx[int(len(Fx)*0.7):])
            min_actual = min(Tx[int(len(Fx)*0.7):])
            
            predicted_tx = (predicted_tx - min_output)/float((max_output - min_output)+0.01)
            
            actual_tx = (actual_tx - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_tx - actual_tx)
        
        if key_counter == 7: 
    
            predicted_ty = output[key_counter][j][0]
            actual_ty = Ty[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Ty[int(len(Fx)*0.7):])
            min_actual = min(Ty[int(len(Fx)*0.7):])
            
            predicted_ty = (predicted_ty - min_output)/float((max_output - min_output)+0.01)
            
            actual_ty = (actual_ty - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_ty - actual_ty)
        
        if key_counter == 8: 
    
            predicted_tz = output[key_counter][j][0]
            actual_tz = Tz[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Tz[int(len(Fx)*0.7):])
            min_actual = min(Tz[int(len(Fx)*0.7):])
            
            predicted_tz = (predicted_tz - min_output)/float((max_output - min_output)+0.01)
            
            actual_tz = (actual_tz - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_tz - actual_tz)
        
        if key_counter == 9: 
    
            predicted_pitch = output[key_counter][j][0]
            actual_pitch = Pitch[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Pitch[int(len(Fx)*0.7):])
            min_actual = min(Pitch[int(len(Fx)*0.7):])
            
            predicted_pitch = (predicted_pitch - min_output)/float((max_output - min_output)+0.01)
            
            actual_pitch = (actual_pitch - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_pitch - actual_pitch)
        
        if key_counter == 10: 
    
            predicted_x = output[key_counter][j][0]
            actual_x = X[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(X[int(len(Fx)*0.7):])
            min_actual = min(X[int(len(Fx)*0.7):])
            
            predicted_x = (predicted_x - min_output)/float((max_output - min_output)+0.01)
            
            actual_x = (actual_x - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_x - actual_x)
        
        if key_counter == 11: 
    
            predicted_y = output[key_counter][j][0]
            actual_y = Y[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Y[int(len(Fx)*0.7):])
            min_actual = min(Y[int(len(Fx)*0.7):])
            
            predicted_y = (predicted_y - min_output)/float((max_output - min_output)+0.01)
            
            actual_y = (actual_y - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_y - actual_y)
        
        if key_counter == 12: 
    
            predicted_z = output[key_counter][j][0]
            actual_z = Z[k]
            
            max_output = max(output[key_counter])[0]
            min_output = min(output[key_counter])[0]
            
            max_actual = max(Z[int(len(Fx)*0.7):])
            min_actual = min(Z[int(len(Fx)*0.7):])
            
            predicted_z = (predicted_z - min_output)/float((max_output - min_output)+0.01)
            
            actual_z = (actual_z - min_actual)/float((max_actual - min_actual)+0.01)
    
    
            error[i] += abs(predicted_z - actual_z)
        
        k += 1
    
    
    error[i] /= np.shape(output)[1]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 0.4235825276668992, 'fy': 0.4194132201931633, 'u0': 0.015381487715727709, 'v0': 0.01648194257168002, 'baseline': 0.5441413221528523, 'disparity': 0.014313188116029978, 'x': 0.31713059071042304, 'y': 0.5167846055541055, 'z': 0.4430270177657204, 'pitch': 0.5165417412806457, 'xworld': 0.34277628655111797, 'yworld': 0.4013255136125008, 'zworld': 0.504711751988128}

# %%
np.shape(output)
# Out:
# (13, 23796, 1)

# %%
k
# Out:
# 79320

# %%
sum(error.values())
# Out:
# 401.2137982147371
