# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_path = "../Data/"


Fx_cvgl = np.load(data_path+"fx.npy")
Fy_cvgl = np.load(data_path+"fy.npy") 
U0_cvgl = np.load(data_path+"u0.npy") 
V0_cvgl = np.load(data_path+"v0.npy") 
Baseline_cvgl = np.load(data_path+"b.npy")
Disparity_cvgl = np.load(data_path+"d.npy") 
Tx_cvgl = np.load(data_path+"tx.npy") 
Ty_cvgl = np.load(data_path+"ty.npy") 
Tz_cvgl = np.load(data_path+"tz.npy") 
Pitch_cvgl = np.load(data_path+"p.npy")
X_cvgl = np.load(data_path+"x.npy")
Y_cvgl = np.load(data_path+"y.npy") 
Z_cvgl = np.load(data_path+"z.npy")

# %%
data_path = "../Data/"


Fx_cyclist = np.load(data_path+"fxr.npy")
Fy_cyclist = np.load(data_path+"fyr.npy") 
U0_cyclist = np.load(data_path+"u0r.npy") 
V0_cyclist = np.load(data_path+"v0r.npy") 
Baseline_cyclist = np.load(data_path+"br.npy")
Disparity_cyclist = np.load(data_path+"dr.npy") 
Tx_cyclist = np.load(data_path+"txr.npy") 
Ty_cyclist = np.load(data_path+"tyr.npy") 
Tz_cyclist = np.load(data_path+"tzr.npy") 
Pitch_cyclist = np.load(data_path+"pr.npy")
X_cyclist = np.load(data_path+"xr.npy")
Y_cyclist = np.load(data_path+"yr.npy") 
Z_cyclist = np.load(data_path+"zr.npy")

# %%
data_path = "../Data/"


Fx_city = np.load(data_path+"fxr_cs.npy")
Fy_city = np.load(data_path+"fyr_cs.npy") 
U0_city = np.load(data_path+"u0r_cs.npy") 
V0_city = np.load(data_path+"v0r_cs.npy") 
Baseline_city = np.load(data_path+"br_cs.npy")
Disparity_city = np.load(data_path+"dr_cs.npy") 
Tx_city = np.load(data_path+"txr_cs.npy") 
Ty_city = np.load(data_path+"tyr_cs.npy") 
Tz_city = np.load(data_path+"tzr_cs.npy") 
Pitch_city = np.load(data_path+"pr_cs.npy")
X_city = np.load(data_path+"xr_cs.npy")
Y_city = np.load(data_path+"yr_cs.npy") 
Z_city = np.load(data_path+"zr_cs.npy")

# %%
np.shape(Fx_cvgl), np.shape(Fx_cyclist), np.shape(Fx_city)
# Out:
# ((123017,), (2914,), (1525,))

# %%
fig = plt.figure(figsize=(6, 6))
plt.scatter(Fx_cvgl[:1525], Fx_cyclist[:1525],Fx_city[:1525])

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Fx_cvgl[:1525], Fx_cyclist[:1525],Fx_city[:1525], linewidths=1, alpha=.7, edgecolor='k', s = 200, c=Fx_city[:1525])
plt.show()

# %%
plt.plot(Fx_cvgl[:1525], Fx_cyclist[:1525],Fx_city[:1525])

# %%
plt.scatter(x=Fx_cvgl[:1525], y=Fx_cyclist[:1525], s=Fx_city[:1525])
plt.show()

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Fy_cvgl[:1525], Fy_cyclist[:1525],Fy_city[:1525], linewidths=1, alpha=.7, edgecolor='k', s = 200, c=Fx_city[:1525])
plt.show()

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(U0_cvgl[:1525], U0_cyclist[:1525],U0_city[:1525], linewidths=1, alpha=.7, edgecolor='k', s = 200, c=Fx_city[:1525])
plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Fx_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Fx_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Fx_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Fx")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Fy_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Fy_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Fy_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Fy")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, U0_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, U0_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, U0_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("U0")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, V0_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, V0_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, V0_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("V0")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Baseline_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Baseline_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Baseline_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Baseline")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Disparity_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Disparity_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Disparity_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Disparity")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Tx_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Tx_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Tx_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Tx")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Ty_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Ty_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Ty_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Ty")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Tz_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Tz_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Tz_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Tz")

plt.show()

# %%
x = np.random.rand(1525)
y = np.random.rand(1525)
plt.rcParams["figure.autolayout"] = True
axes = plt.subplot(111, projection='3d')
axes.plot(x, y, Pitch_cvgl[:1525], "*", label="CVGL")
axes.plot(x, y, Pitch_cyclist[:1525], "o", label="Tsinghua-Daimler")
axes.plot(x, y, Pitch_city[:1525], "+", label="Cityscapes")

plt.legend(loc="upper right")
plt.title("Pitch")

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.boxplot([Fx_cvgl, Fy_cvgl, U0_cvgl, V0_cvgl, Baseline_cvgl, Disparity_cvgl, Pitch_cvgl, Tx_cvgl, Ty_cvgl, Tz_cvgl])

ax.set_title('CVGL')


plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.boxplot([Fx_cyclist, Fy_cyclist, U0_cyclist, V0_cyclist, Baseline_cyclist, Disparity_cyclist, Pitch_cyclist, Tx_cyclist, Ty_cyclist, Tz_cyclist])

ax.set_title('Tsinghua-Daimler')


plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.boxplot([Fx_city, Fy_city, U0_city, V0_city, Baseline_city, Disparity_city, Pitch_city, Tx_city, Ty_city, Tz_city])

ax.set_title('Cityscapes')


plt.show()

# %%
min(Fx_cvgl),np.mean(Fx_cvgl),max(Fx_cvgl)
# Out:
# (15.00515477614287, 59.20985328142693, 120.09238754853529)

# %%
min(Fy_cvgl),np.mean(Fy_cvgl),max(Fy_cvgl)
# Out:
# (15.00515477614287, 59.20985328142693, 120.09238754853529)

# %%
min(U0_cvgl),np.mean(U0_cvgl),max(U0_cvgl)
# Out:
# (56.0, 56.0, 56.0)

# %%
min(V0_cvgl),np.mean(V0_cvgl),max(V0_cvgl)
# Out:
# (56.0, 56.0, 56.0)

# %%
min(Baseline_cvgl),np.mean(Baseline_cvgl),max(Baseline_cvgl)
# Out:
# (-168.0, -83.8703187364348, 0.0)

# %%
min(Disparity_cvgl),np.mean(Disparity_cvgl),max(Disparity_cvgl)
# Out:
# (-16.0, -10.966165226660847, 14.531648596938776)

# %%
min(Pitch_cvgl),np.mean(Pitch_cvgl),max(Pitch_cvgl)
# Out:
# (-45.0, -12.23574790476113, 15.0)

# %%
min(Tx_cvgl),np.mean(Tx_cvgl),max(Tx_cvgl)
# Out:
# (-168.0, -83.8703187364348, 0.0)

# %%
min(Ty_cvgl),np.mean(Ty_cvgl),max(Ty_cvgl)
# Out:
# (-5.0, 0.42506320264678865, 5.0)

# %%
min(Tz_cvgl),np.mean(Tz_cvgl),max(Tz_cvgl)
# Out:
# (-1.6, -0.5726541860068118, 0.4)

# %%
min(Fx_cyclist),np.mean(Fx_cyclist),max(Fx_cyclist)
# Out:
# (2282.864502, 2282.864502, 2282.864502)

# %%
min(Fy_cyclist),np.mean(Fy_cyclist),max(Fy_cyclist)
# Out:
# (2281.7943404543266, 2281.7943404543257, 2281.7943404543266)

# %%
min(U0_cyclist),np.mean(U0_cyclist),max(U0_cyclist)
# Out:
# (1042.04126, 1042.04126, 1042.04126)

# %%
min(V0_cyclist),np.mean(V0_cyclist),max(V0_cyclist)
# Out:
# (529.888062, 529.888062, 529.888062)

# %%
min(Baseline_cyclist),np.mean(Baseline_cyclist),max(Baseline_cyclist)
# Out:
# (0.208811, 0.20881100000000002, 0.208811)

# %%
min(Disparity_cyclist),np.mean(Disparity_cyclist),max(Disparity_cyclist)
# Out:
# (-6.75390625, 21.455680014584765, 83.09375)

# %%
min(Tx_cyclist),np.mean(Tx_cyclist),max(Tx_cyclist)
# Out:
# (2.0, 2.0, 2.0)

# %%
min(Ty_cyclist),np.mean(Ty_cyclist),max(Ty_cyclist)
# Out:
# (0.125, 0.125, 0.125)

# %%
min(Tz_cyclist),np.mean(Tz_cyclist),max(Tz_cyclist)
# Out:
# (1.23, 1.2300000000000002, 1.23)

# %%
min(Pitch_cyclist),np.mean(Pitch_cyclist),max(Pitch_cyclist)
# Out:
# (0.022, 0.021999999999999995, 0.022)

# %%
min(Fx_city),np.mean(Fx_city),max(Fx_city)
# Out:
# (2262.52, 2264.256629508197, 2268.36)

# %%
min(Fy_city),np.mean(Fy_city),max(Fy_city)
# Out:
# (2225.5405988775956, 2253.738949164428, 2265.3017905988554)

# %%
min(U0_city),np.mean(U0_city),max(U0_city)
# Out:
# (1045.53, 1081.1887606557377, 1096.98)

# %%
min(V0_city),np.mean(V0_city),max(V0_city)
# Out:
# (513.137, 514.9883770491801, 519.277)

# %%
min(Baseline_city),np.mean(Baseline_city),max(Baseline_city)
# Out:
# (0.209313, 0.21338424524590163, 0.222365)

# %%
min(Disparity_city),np.mean(Disparity_city),max(Disparity_city)
# Out:
# (-4.67578125, 15.539082991803278, 57.33984375)

# %%
min(Tx_city),np.mean(Tx_city),max(Tx_city)
# Out:
# (1.7, 1.6999999999999995, 1.7)

# %%
min(Ty_city),np.mean(Ty_city),max(Ty_city)
# Out:
# (-0.1, 0.037180327868852454, 0.1)

# %%
min(Tz_city),np.mean(Tz_city),max(Tz_city)
# Out:
# (1.18, 1.2308852459016395, 1.3)

# %%
min(Pitch_city),np.mean(Pitch_city),max(Pitch_city)
# Out:
# (0.038, 0.041769180327868846, 0.05)

# %%
plt.hist(Fx_cvgl, 30, alpha=0.5, label='CVGL')
plt.hist(Fx_cyclist, 30, alpha=0.5, label='Tsinghua-Daimler')
plt.hist(Fx_city, 30, alpha=0.5, label='Cityscapes')
plt.legend(loc='upper right')
plt.show()

# %%
plt.hist(Fy_cvgl, 30, alpha=0.5, label='CVGL')
plt.hist(Fy_cyclist, 30, alpha=0.5, label='Tsinghua-Daimler')
plt.hist(Fy_city, 30, alpha=0.5, label='Cityscapes')
plt.legend(loc='upper right')
plt.show()

# %%
plt.hist(U0_cvgl, 30, alpha=0.5, label='CVGL')
plt.hist(U0_cyclist, 30, alpha=0.5, label='Tsinghua-Daimler')
plt.hist(U0_city, 30, alpha=0.5, label='Cityscapes')
plt.legend(loc='upper right')
plt.show()
