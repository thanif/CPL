# %%
import tensorflow as tf
tf.set_random_seed(1)
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
import matplotlib.pyplot as plt
import PIL.Image as Image
import math
import numpy as np
import keras.backend as K
from keras.utils import plot_model
import json
from keras.losses import mse
import os
import glob
import random
import cv2
from sklearn.model_selection import train_test_split
from keras.applications.inception_v3 import InceptionV3
import datetime
from keras.layers import Dense, Input, concatenate, Conv2D, MaxPooling2D, Flatten, Lambda
from keras.models import Model
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.callbacks import TensorBoard
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def add_layer(tensor):
    return tensor[0] + tensor[1]

def mul_layer(tensor):
    return tensor[0] * tensor[1]

def div_layer(tensor):
    return tensor[0] / tensor[1]

def sub_layer(tensor):
    return tensor[0] - tensor[1]

def neg_layer(tensor):
    return -tensor

def cos_layer(tensor):
    return tf.math.cos(tensor)

def sin_layer(tensor):
    return tf.math.sin(tensor)

# %% [markdown]
# # Model

# %%
# feature extraction from left image
left_img = Input(shape = (112,112,3), name="left_image")

# feature extraction from right image
right_img = Input(shape = (112,112,3), name="right_image")

left_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=left_img, input_shape=(112,112,3))
left_phi_features = left_phi_model.output
left_flat = Flatten(name='left-phi-flattened')(left_phi_features)

right_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=right_img, input_shape=(112,112,3))
right_phi_features = right_phi_model.output
right_flat = Flatten(name='right-phi-flattened')(right_phi_features)

concat = concatenate([left_flat, right_flat])

# fx
dense_1 = Dense(120, activation = 'relu')(concat)
dense_2 = Dense(84, activation = 'relu')(dense_1)
pred_fx = Dense(1, name='fx')(dense_2)

# fy
dense_3 = Dense(120, activation = 'relu')(concat)
dense_4 = Dense(84, activation = 'relu')(dense_3)
pred_fy = Dense(1, name='fy')(dense_4)

# u0
dense_5 = Dense(120, activation = 'relu')(concat)
dense_6 = Dense(84, activation = 'relu')(dense_5)
pred_u0 = Dense(1, name='u0')(dense_6)

# v0
dense_7 = Dense(120, activation = 'relu')(concat)
dense_8 = Dense(84, activation = 'relu')(dense_7)
pred_v0 = Dense(1, name='v0')(dense_8)

# baseline
dense_9 = Dense(120, activation = 'relu')(concat)
dense_10 = Dense(84, activation = 'relu')(dense_9)
pred_baseline = Dense(1, name='baseline')(dense_10)

# tx
dense_11 = Dense(120, activation = 'relu')(concat)
dense_12 = Dense(84, activation = 'relu')(dense_11)
pred_x = Dense(1, name='x')(dense_12)

# ty
dense_13 = Dense(120, activation = 'relu')(concat)
dense_14 = Dense(84, activation = 'relu')(dense_13)
pred_y = Dense(1, name='y')(dense_14)

# tz
dense_15 = Dense(120, activation = 'relu')(concat)
dense_16 = Dense(84, activation = 'relu')(dense_15)
pred_z = Dense(1, name='z')(dense_16)

# pitch
dense_17 = Dense(120, activation = 'relu')(concat)
dense_18 = Dense(84, activation = 'relu')(dense_17)
pred_pitch = Dense(1, name='pitch')(dense_18)

# u
dense_19 = Dense(120, activation = 'relu')(concat)
dense_20 = Dense(84, activation = 'relu')(dense_19)
pred_u = Dense(1, name='u')(dense_20)

# v
dense_21 = Dense(120, activation = 'relu')(concat)
dense_22 = Dense(84, activation = 'relu')(dense_21)
pred_v = Dense(1, name='v')(dense_22)

# disparity
dense_23 = Dense(120, activation = 'relu')(concat)
dense_24 = Dense(84, activation = 'relu')(dense_23)
pred_disparity = Dense(1, name='disparity')(dense_24)

# yWorld
dense_25 = Dense(120, activation = 'relu')(concat)
dense_26 = Dense(84, activation = 'relu')(dense_25)
pred_yWorld = Dense(1, name='yWorld')(dense_26)

# xWorld
dense_27 = Dense(120, activation = 'relu')(concat)
dense_28 = Dense(84, activation = 'relu')(dense_27)
pred_xWorld = Dense(1, name='xWorld')(dense_28)

# zWorld
dense_29 = Dense(120, activation = 'relu')(concat)
dense_30 = Dense(84, activation = 'relu')(dense_29)
pred_zWorld = Dense(1, name='zWorld')(dense_30)

# create model
model = Model(inputs=[left_img, right_img], outputs=[pred_fx, pred_fy, pred_u0, pred_v0, pred_baseline, pred_disparity, pred_x, pred_y, pred_z, pred_pitch, pred_xWorld,pred_yWorld,pred_zWorld])

# set output types
target1 = tf.placeholder(dtype='float32', shape=(1,1)) 
target2 = tf.placeholder(dtype='float32', shape=(1,1))
target3 = tf.placeholder(dtype='float32', shape=(1,1))
target4 = tf.placeholder(dtype='float32', shape=(1,1)) 
target5 = tf.placeholder(dtype='float32', shape=(1,1))
target6 = tf.placeholder(dtype='float32', shape=(1,1))
target7 = tf.placeholder(dtype='float32', shape=(1,1)) 
target8 = tf.placeholder(dtype='float32', shape=(1,1))
target9 = tf.placeholder(dtype='float32', shape=(1,1))
target10 = tf.placeholder(dtype='float32', shape=(1,1)) 
target11 = tf.placeholder(dtype='float32', shape=(1,1))
target12 = tf.placeholder(dtype='float32', shape=(1,1))
target13 = tf.placeholder(dtype='float32', shape=(1,1))

# get model summary
model.summary()

learning_rate = 0.001

# compile model
model.compile(loss="mae", target_tensors=[target1, target2, target3, target4, target5, target6, target7, target8, target9, target10, target11, target12, target13],optimizer=optimizers.Adam(lr=learning_rate))
plot_model(model, to_file='model.png')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0130 08:17:35.207660 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0130 08:17:35.211418 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0130 08:17:35.240583 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0130 08:17:35.262300 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0130 08:17:35.263245 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0130 08:17:35.675487 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0130 08:17:35.899412 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0130 08:17:36.568079 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_image (InputLayer)         (None, 112, 112, 3)  0
# __________________________________________________________________________________________________
# right_image (InputLayer)        (None, 112, 112, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 55, 55, 32)   864         left_image[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 55, 55, 32)   864         right_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 55, 55, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 55, 55, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 55, 55, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 55, 55, 32)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 53, 53, 32)   9216        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 53, 53, 32)   9216        activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 53, 53, 32)   96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 53, 53, 32)   96          conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 53, 53, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 53, 53, 32)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 53, 53, 64)   18432       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 53, 53, 64)   18432       activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 53, 53, 64)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 53, 53, 64)   192         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 53, 53, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 53, 53, 64)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 26, 26, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 26, 26, 64)   0           activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 26, 26, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 26, 26, 80)   5120        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 26, 26, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 26, 26, 80)   240         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 26, 26, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 26, 26, 80)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 24, 24, 192)  138240      activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 24, 24, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 24, 24, 192)  576         conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 24, 24, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 24, 24, 192)  0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 11, 11, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 11, 11, 192)  0           activation_99[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 11, 11, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 11, 11, 64)   12288       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 11, 11, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 11, 11, 64)   192         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 11, 11, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 11, 11, 64)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 11, 11, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 11, 11, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 11, 11, 48)   9216        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 11, 11, 96)   55296       activation_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 11, 11, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 11, 11, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 11, 11, 48)   144         conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 11, 11, 96)   288         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 11, 11, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 11, 11, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 11, 11, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 11, 11, 48)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 11, 11, 96)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 11, 11, 192)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 11, 11, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 11, 11, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 11, 11, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 11, 11, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 11, 11, 64)   12288       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 11, 11, 64)   76800       activation_101[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 11, 11, 96)   82944       activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 11, 11, 32)   6144        average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 11, 11, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 11, 11, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 11, 11, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 11, 11, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 11, 11, 64)   192         conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 11, 11, 64)   192         conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 11, 11, 96)   288         conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 11, 11, 32)   96          conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 11, 11, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 11, 11, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 11, 11, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 11, 11, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 11, 11, 64)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 11, 11, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 11, 11, 96)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 11, 11, 32)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 11, 11, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 11, 11, 256)  0           activation_100[0][0]
#                                                                  activation_102[0][0]
#                                                                  activation_105[0][0]
#                                                                  activation_106[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 11, 11, 64)   16384       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 11, 11, 64)   16384       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 11, 11, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 11, 11, 64)   192         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 11, 11, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 11, 11, 64)   0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 11, 11, 48)   12288       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 11, 11, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 11, 11, 48)   12288       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 11, 11, 96)   55296       activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 11, 11, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 11, 11, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 11, 11, 48)   144         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 11, 11, 96)   288         conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 11, 11, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 11, 11, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 11, 11, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 11, 11, 48)   0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 11, 11, 96)   0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 11, 11, 256)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 11, 11, 64)   16384       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 11, 11, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 11, 11, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 11, 11, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 11, 11, 64)   16384       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 11, 11, 64)   76800       activation_108[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 11, 11, 96)   82944       activation_111[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 11, 11, 64)   16384       average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 11, 11, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 11, 11, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 11, 11, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 11, 11, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 11, 11, 64)   192         conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 11, 11, 64)   192         conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 11, 11, 96)   288         conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 11, 11, 64)   192         conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 11, 11, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 11, 11, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 11, 11, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 11, 11, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 11, 11, 64)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 11, 11, 64)   0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 11, 11, 96)   0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 11, 11, 64)   0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 11, 11, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 11, 11, 288)  0           activation_107[0][0]
#                                                                  activation_109[0][0]
#                                                                  activation_112[0][0]
#                                                                  activation_113[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 11, 11, 64)   18432       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 11, 11, 64)   18432       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 11, 11, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 11, 11, 64)   192         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 11, 11, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 11, 11, 64)   0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 11, 11, 48)   13824       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 11, 11, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 11, 11, 48)   13824       concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 11, 11, 96)   55296       activation_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 11, 11, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 11, 11, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 11, 11, 48)   144         conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 11, 11, 96)   288         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 11, 11, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 11, 11, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 11, 11, 288)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 11, 11, 48)   0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 11, 11, 96)   0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 11, 11, 288)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 11, 11, 64)   18432       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 11, 11, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 11, 11, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 11, 11, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 11, 11, 64)   18432       concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 11, 11, 64)   76800       activation_115[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 11, 11, 96)   82944       activation_118[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 11, 11, 64)   18432       average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 11, 11, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 11, 11, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 11, 11, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 11, 11, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 11, 11, 64)   192         conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 11, 11, 64)   192         conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 11, 11, 96)   288         conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 11, 11, 64)   192         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 11, 11, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 11, 11, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 11, 11, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 11, 11, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 11, 11, 64)   0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 11, 11, 64)   0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 11, 11, 96)   0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 11, 11, 64)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 11, 11, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 11, 11, 288)  0           activation_114[0][0]
#                                                                  activation_116[0][0]
#                                                                  activation_119[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 11, 11, 64)   18432       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 11, 11, 64)   18432       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 11, 11, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 11, 11, 64)   192         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 11, 11, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 11, 11, 64)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 11, 11, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 11, 11, 96)   55296       activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 11, 11, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 11, 11, 96)   288         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 11, 11, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 11, 11, 96)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 5, 5, 384)    995328      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 5, 5, 96)     82944       activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 5, 5, 384)    995328      concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 5, 5, 96)     82944       activation_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 5, 5, 384)    1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 5, 5, 96)     288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 5, 5, 384)    1152        conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 5, 5, 96)     288         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 5, 5, 384)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 5, 5, 96)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 5, 288)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 5, 5, 384)    0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 5, 5, 96)     0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 5, 5, 288)    0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 5, 5, 768)    0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 5, 5, 768)    0           activation_121[0][0]
#                                                                  activation_124[0][0]
#                                                                  max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 5, 5, 128)    98304       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 5, 5, 128)    98304       concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 5, 5, 128)    384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 5, 5, 128)    384         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 5, 5, 128)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 5, 5, 128)    0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 5, 5, 128)    114688      activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 5, 5, 128)    114688      activation_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 5, 5, 128)    384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 5, 5, 128)    384         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 5, 5, 128)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 5, 5, 128)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 5, 5, 128)    98304       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 5, 5, 128)    114688      activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 5, 5, 128)    98304       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 5, 5, 128)    114688      activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 5, 5, 128)    384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 5, 5, 128)    384         conv2d_37[0][0]
# ...
# batch_normalization_92 (BatchNo (None, 2, 2, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 2, 2, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 2, 2, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 2, 2, 320)    655360      concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 2, 2, 384)    1152        conv2d_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 2, 2, 384)    1152        conv2d_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 2, 2, 384)    1152        conv2d_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 2, 2, 384)    1152        conv2d_187[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 2, 2, 192)    393216      average_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 2, 2, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 2, 2, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 2, 2, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 2, 2, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 2, 2, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 2, 2, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 2, 2, 320)    960         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 2, 2, 384)    0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 2, 2, 384)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 2, 2, 384)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 2, 2, 384)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 2, 2, 192)    576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 2, 2, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# W0130 08:18:02.548737 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# concatenate_13 (Concatenate)    (None, 2, 2, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 2, 2, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 2, 2, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 2, 2, 320)    0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 2, 2, 768)    0           activation_182[0][0]
#                                                                  activation_183[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 2, 2, 768)    0           activation_186[0][0]
#                                                                  activation_187[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 2, 2, 192)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 2, 2, 2048)   0           activation_86[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 2, 2, 2048)   0           activation_180[0][0]
#                                                                  concatenate_28[0][0]
#                                                                  concatenate_29[0][0]
#                                                                  activation_188[0][0]
# __________________________________________________________________________________________________
# left-phi-flattened (Flatten)    (None, 8192)         0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# right-phi-flattened (Flatten)   (None, 8192)         0           concatenate_30[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 16384)        0           left-phi-flattened[0][0]
#                                                                  right-phi-flattened[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 120)          1966200     concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 84)           10164       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 84)           10164       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 84)           10164       dense_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 84)           10164       dense_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 84)           10164       dense_9[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 84)           10164       dense_23[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 84)           10164       dense_11[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 84)           10164       dense_13[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 84)           10164       dense_15[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 84)           10164       dense_17[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 84)           10164       dense_27[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 84)           10164       dense_25[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 84)           10164       dense_29[0][0]
# __________________________________________________________________________________________________
# fx (Dense)                      (None, 1)            85          dense_2[0][0]
# __________________________________________________________________________________________________
# fy (Dense)                      (None, 1)            85          dense_4[0][0]
# __________________________________________________________________________________________________
# u0 (Dense)                      (None, 1)            85          dense_6[0][0]
# __________________________________________________________________________________________________
# v0 (Dense)                      (None, 1)            85          dense_8[0][0]
# __________________________________________________________________________________________________
# baseline (Dense)                (None, 1)            85          dense_10[0][0]
# __________________________________________________________________________________________________
# disparity (Dense)               (None, 1)            85          dense_24[0][0]
# __________________________________________________________________________________________________
# x (Dense)                       (None, 1)            85          dense_12[0][0]
# __________________________________________________________________________________________________
# y (Dense)                       (None, 1)            85          dense_14[0][0]
# __________________________________________________________________________________________________
# z (Dense)                       (None, 1)            85          dense_16[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 1)            85          dense_18[0][0]
# __________________________________________________________________________________________________
# xWorld (Dense)                  (None, 1)            85          dense_28[0][0]
# __________________________________________________________________________________________________
# yWorld (Dense)                  (None, 1)            85          dense_26[0][0]
# __________________________________________________________________________________________________
# zWorld (Dense)                  (None, 1)            85          dense_30[0][0]
# ==================================================================================================
# Total params: 69,299,405
# Trainable params: 69,230,541
# Non-trainable params: 68,864
# __________________________________________________________________________________________________

# %% [markdown]
# # Get data

# %% [markdown]
# xCam = (self.intrinsic.fx * self.extrinsic.baseline) / disparity
#
# yCam = - (xCam / self.intrinsic.fx) * (u - self.intrinsic.u0)
#
# zCam = (xCam / self.intrinsic.fy) * (self.intrinsic.v0 - v)
#
# yWorld = yCam + self.extrinsic.y
#
# xWorld = xCam * math.cos(self.extrinsic.pitch) + zCam * \
#             math.sin(self.extrinsic.pitch) + self.extrinsic.x
#
# zWorld = - xCam * math.sin(self.extrinsic.pitch) + zCam * \
#             math.cos(self.extrinsic.pitch) + self.extrinsic.z
#
# Focal_length = ImageSizeX /(2 * tan(CameraFOV * π / 360))
#
# Center_X = ImageSizeX / 2
#
# Center_Y = ImageSizeY / 2

# %% [markdown]
# ## Town 1

# %%
data_path = "../../Carla/data-collector-master/Datasets/Town2/"

new_size = (112, 112) 

Left_images = []
Right_images = []
Disparity = []
Tx = []
Ty = []
Tz = []
Baseline = []
Pitch = []
Fx = []
Fy = []
U0 = []
V0 = []
X = []
Y = []
Z = []


for folder in os.listdir(data_path):
    
    if "episode" in folder:
    
        episode_data = os.listdir(data_path+folder)
        
        file = open(data_path+folder+"/params.txt", "r")

        i = 0

        for line in file:
    
            if ":" in line:
        
                if i == 0:
        
                    fov = int(line.split(":")[1])
            
                elif i == 1:
            
                    x = int(line.split(":")[1])
            
                elif i == 2:
            
                    y = int(line.split(":")[1])
            
                elif i == 3:
            
                    z = int(line.split(":")[1])
            
                elif i == 4:
            
                    p = int(line.split(":")[1])
            
                elif i == 5:
            
                    yaw = int(line.split(":")[1])
            
                elif i == 6:
            
                    roll = int(line.split(":")[1])
            
            i += 1
        
        
        for fname in episode_data:
        
            if "Left" in fname:
                
                l_im = cv2.imread(data_path+folder+"/"+fname, 0)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1], 0)
                stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
                disparity_map = stereo.compute(l_im, r_im)
                disparity_value = np.mean(disparity_map)
        
                l_im = cv2.imread(data_path+folder+"/"+fname)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1])
        
                Left_images.append(l_im)
                Right_images.append(r_im)
                Disparity.append(disparity_value)
                Tx.append(x)
                Ty.append(y)
                Tz.append(z)
                Baseline.append(x)
                Pitch.append(p)
                focal_length = new_size[0]/(2*np.tan(fov*np.pi/360))
                center_x = new_size[0]/2
                center_y = center_x
                Fx.append(focal_length)
                Fy.append(focal_length)
                U0.append(center_x)
                V0.append(center_y)
                
                xCam = (focal_length * x) / disparity_value
                yCam = - (xCam / focal_length) * (5 - center_x)
                zCam = (xCam / focal_length) * (center_y - 5)

                yWorld = yCam + y
                xWorld = xCam * math.cos(p) + zCam*math.sin(p) + x
                zWorld = - xCam * math.sin(p) + zCam*math.cos(p) + z
        
                X.append(xWorld)
                Y.append(yWorld)
                Z.append(zWorld)

# %% [markdown]
# ## Town 2

# %%
data_path = "../../Carla/data-collector-master/Datasets/Town1/"

new_size = (112, 112) 


for folder in os.listdir(data_path):
    
    if "episode" in folder:
    
        episode_data = os.listdir(data_path+folder)
        
        file = open(data_path+folder+"/params.txt", "r")

        i = 0

        for line in file:
    
            if ":" in line:
        
                if i == 0:
        
                    fov = int(line.split(":")[1])
            
                elif i == 1:
            
                    x = int(line.split(":")[1])
            
                elif i == 2:
            
                    y = int(line.split(":")[1])
            
                elif i == 3:
            
                    z = int(line.split(":")[1])
            
                elif i == 4:
            
                    p = int(line.split(":")[1])
            
                elif i == 5:
            
                    yaw = int(line.split(":")[1])
            
                elif i == 6:
            
                    roll = int(line.split(":")[1])
            
            i += 1
        
        
        for fname in episode_data:
        
            if "Left" in fname:
                
                l_im = cv2.imread(data_path+folder+"/"+fname, 0)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1], 0)
                stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
                disparity_map = stereo.compute(l_im, r_im)
                disparity_value = np.mean(disparity_map)
        
                l_im = cv2.imread(data_path+folder+"/"+fname)
                r_im = cv2.imread(data_path+folder+"/"+'RightRGB_'+fname.split("_")[1])
        
                Left_images.append(l_im)
                Right_images.append(r_im)
                Disparity.append(disparity_value)
                Tx.append(x)
                Ty.append(y)
                Tz.append(z)
                Baseline.append(x)
                Pitch.append(p)
                focal_length = new_size[0]/(2*np.tan(fov*np.pi/360))
                center_x = new_size[0]/2
                center_y = center_x
                Fx.append(focal_length)
                Fy.append(focal_length)
                U0.append(center_x)
                V0.append(center_y)
                
                xCam = (focal_length * x) / disparity_value
                yCam = - (xCam / focal_length) * (5 - center_x)
                zCam = (xCam / focal_length) * (center_y - 5)

                yWorld = yCam + y
                xWorld = xCam * math.cos(p) + zCam*math.sin(p) + x
                zWorld = - xCam * math.sin(p) + zCam*math.cos(p) + z
        
                X.append(xWorld)
                Y.append(yWorld)
                Z.append(zWorld)

# %%
print ("dataset: ",np.shape(Z))
# Out:
# dataset:  (79320,)

# %%
print ("Training Dataset: ",len(Left_images)*0.7, "Test Dataset: ", len(Left_images)*0.3)
# Out:
# Training Dataset:  55524.0 Test Dataset:  23796.0

# %%
c = list(zip(Left_images, Right_images, Fx, Fy, U0, V0, Baseline, Disparity, Tx, Ty, Tz, Pitch, X, Y, Z))
random.shuffle(c)
Left_images, Right_images, Fx, Fy, U0, V0, Baseline, Disparity, Tx, Ty, Tz, Pitch, X, Y, Z = zip(*c)
Left_images, Right_images, Fx, Fy, U0, V0, Baseline, Disparity, Tx, Ty, Tz, Pitch, X, Y, Z = list(Left_images), list(Right_images), list(Fx), list(Fy), list(U0), list(V0), list(Baseline), list(Disparity), list(Tx), list(Ty), list(Tz), list(Pitch), list(X), list(Y), list(Z)

# %%
import os
from keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

model_name = 'model_multi_class/'
SAVE = "new_logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '/'
# Save
output_folder = SAVE + model_name
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

output_log = output_folder + "Log/"
if not os.path.exists(output_log):
    os.makedirs(output_log)

output_weight = output_folder + "Best/"
if not os.path.exists(output_weight):
    os.makedirs(output_weight)


input_shape = (112, 112, 3)

tensorboard = TensorBoard(log_dir=output_log)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto', restore_best_weights=True)

csv_logger = CSVLogger('training.log')

checkpointer = CustomModelCheckpoint(
    model_for_saving=model,
    filepath=output_weight + "weights_{epoch:02d}_{val_loss:.2f}.h5",
    save_best_only=True,
    monitor='val_loss',
    save_weights_only=True
)

history = model.fit(
    x=[Left_images[:int(len(Left_images)*0.7)], Right_images[:int(len(Left_images)*0.7)]],
    y=[Fx[:int(len(Left_images)*0.7)], Fy[:int(len(Left_images)*0.7)], U0[:int(len(Left_images)*0.7)], V0[:int(len(Left_images)*0.7)], Baseline[:int(len(Left_images)*0.7)], Disparity[:int(len(Left_images)*0.7)], Tx[:int(len(Left_images)*0.7)], Ty[:int(len(Left_images)*0.7)], Tz[:int(len(Left_images)*0.7)], Pitch[:int(len(Left_images)*0.7)], X[:int(len(Left_images)*0.7)], Y[:int(len(Left_images)*0.7)], Z[:int(len(Left_images)*0.7)]],
    batch_size=16,
    epochs=200,
    verbose=1,
    shuffle=True,
    initial_epoch=0,
    validation_data=([Left_images[int(len(Left_images)*0.7):], Right_images[int(len(Left_images)*0.7):]], [Fx[int(len(Left_images)*0.7):], Fy[int(len(Left_images)*0.7):], U0[int(len(Left_images)*0.7):], V0[int(len(Left_images)*0.7):], Baseline[int(len(Left_images)*0.7):], Disparity[int(len(Left_images)*0.7):], Tx[int(len(Left_images)*0.7):], Ty[int(len(Left_images)*0.7):], Tz[int(len(Left_images)*0.7):], Pitch[int(len(Left_images)*0.7):], X[int(len(Left_images)*0.7):], Y[int(len(Left_images)*0.7):], Z[int(len(Left_images)*0.7):]]),
    callbacks=[tensorboard, checkpointer, early_stopping, csv_logger]
)
# Out:
# Train on 55524 samples, validate on 23796 samples
# W0130 08:54:57.108299 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0130 08:54:57.139992 140619537528640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/200
# 55524/55524 [==============================] - 918s 17ms/step - loss: 57.6492 - fx_loss: 9.5094 - fy_loss: 9.6169 - u0_loss: 1.4331 - v0_loss: 1.4569 - baseline_loss: 0.5588 - disparity_loss: 0.1732 - x_loss: 0.5509 - y_loss: 0.7032 - z_loss: 0.5936 - pitch_loss: 6.3135 - xWorld_loss: 9.3466 - yWorld_loss: 4.6289 - zWorld_loss: 12.7643 - val_loss: 123.1340 - val_fx_loss: 20.9066 - val_fy_loss: 23.9825 - val_u0_loss: 14.6384 - val_v0_loss: 13.9526 - val_baseline_loss: 1.0689 - val_disparity_loss: 1.3572 - val_x_loss: 0.8942 - val_y_loss: 1.0105 - val_z_loss: 1.0153 - val_pitch_loss: 20.0252 - val_xWorld_loss: 5.8472 - val_yWorld_loss: 7.7687 - val_zWorld_loss: 10.6668
# Epoch 2/200
# 55524/55524 [==============================] - 876s 16ms/step - loss: 20.5988 - fx_loss: 3.1426 - fy_loss: 3.1457 - u0_loss: 0.5350 - v0_loss: 0.5604 - baseline_loss: 0.2369 - disparity_loss: 0.0678 - x_loss: 0.2312 - y_loss: 0.3480 - z_loss: 0.2718 - pitch_loss: 2.0724 - xWorld_loss: 3.4368 - yWorld_loss: 1.9043 - zWorld_loss: 4.6457 - val_loss: 1637.7179 - val_fx_loss: 348.9986 - val_fy_loss: 337.9992 - val_u0_loss: 200.6062 - val_v0_loss: 202.4564 - val_baseline_loss: 5.2657 - val_disparity_loss: 19.3505 - val_x_loss: 5.3088 - val_y_loss: 8.8832 - val_z_loss: 5.8406 - val_pitch_loss: 253.3472 - val_xWorld_loss: 100.6346 - val_yWorld_loss: 83.1060 - val_zWorld_loss: 65.9209
# Epoch 3/200
# 55524/55524 [==============================] - 880s 16ms/step - loss: 14.0735 - fx_loss: 2.1299 - fy_loss: 2.0589 - u0_loss: 0.3770 - v0_loss: 0.3736 - baseline_loss: 0.1705 - disparity_loss: 0.0481 - x_loss: 0.1641 - y_loss: 0.2242 - z_loss: 0.1632 - pitch_loss: 1.3679 - xWorld_loss: 2.4071 - yWorld_loss: 1.3323 - zWorld_loss: 3.2566 - val_loss: 3840.8880 - val_fx_loss: 858.5127 - val_fy_loss: 552.7002 - val_u0_loss: 423.7092 - val_v0_loss: 423.6178 - val_baseline_loss: 21.2670 - val_disparity_loss: 40.8240 - val_x_loss: 22.5433 - val_y_loss: 14.4376 - val_z_loss: 25.9206 - val_pitch_loss: 621.3705 - val_xWorld_loss: 386.1662 - val_yWorld_loss: 215.0843 - val_zWorld_loss: 234.7347
# Epoch 4/200
# 55524/55524 [==============================] - 881s 16ms/step - loss: 11.8146 - fx_loss: 1.6723 - fy_loss: 1.6116 - u0_loss: 0.3480 - v0_loss: 0.3584 - baseline_loss: 0.1433 - disparity_loss: 0.0432 - x_loss: 0.1416 - y_loss: 0.1654 - z_loss: 0.1270 - pitch_loss: 1.1762 - xWorld_loss: 2.0086 - yWorld_loss: 1.1448 - zWorld_loss: 2.8742 - val_loss: 1354.2599 - val_fx_loss: 301.7729 - val_fy_loss: 258.2153 - val_u0_loss: 142.9633 - val_v0_loss: 142.4878 - val_baseline_loss: 8.1946 - val_disparity_loss: 14.3553 - val_x_loss: 6.5081 - val_y_loss: 5.0487 - val_z_loss: 8.8922 - val_pitch_loss: 200.9117 - val_xWorld_loss: 115.1066 - val_yWorld_loss: 56.4705 - val_zWorld_loss: 93.3329
# Epoch 5/200
# 55524/55524 [==============================] - 881s 16ms/step - loss: 9.9232 - fx_loss: 1.3794 - fy_loss: 1.2975 - u0_loss: 0.2703 - v0_loss: 0.2798 - baseline_loss: 0.1266 - disparity_loss: 0.0388 - x_loss: 0.1241 - y_loss: 0.1362 - z_loss: 0.1032 - pitch_loss: 0.9365 - xWorld_loss: 1.7735 - yWorld_loss: 0.9923 - zWorld_loss: 2.4650 - val_loss: 1189.3629 - val_fx_loss: 256.9615 - val_fy_loss: 214.8283 - val_u0_loss: 124.3315 - val_v0_loss: 123.1437 - val_baseline_loss: 4.2702 - val_disparity_loss: 11.5204 - val_x_loss: 4.7498 - val_y_loss: 4.9588 - val_z_loss: 7.8084 - val_pitch_loss: 169.4097 - val_xWorld_loss: 80.1729 - val_yWorld_loss: 69.7126 - val_zWorld_loss: 117.4953
# Epoch 6/200
# 55524/55524 [==============================] - 881s 16ms/step - loss: 8.6646 - fx_loss: 1.1931 - fy_loss: 1.1167 - u0_loss: 0.2901 - v0_loss: 0.2672 - baseline_loss: 0.1105 - disparity_loss: 0.0348 - x_loss: 0.1094 - y_loss: 0.1179 - z_loss: 0.0869 - pitch_loss: 0.8199 - xWorld_loss: 1.5682 - yWorld_loss: 0.8649 - zWorld_loss: 2.0850 - val_loss: 3475.1692 - val_fx_loss: 780.3255 - val_fy_loss: 548.6550 - val_u0_loss: 334.2101 - val_v0_loss: 328.2375 - val_baseline_loss: 18.1632 - val_disparity_loss: 32.1120 - val_x_loss: 17.7266 - val_y_loss: 17.0656 - val_z_loss: 21.6630 - val_pitch_loss: 480.1316 - val_xWorld_loss: 331.0768 - val_yWorld_loss: 204.1228 - val_zWorld_loss: 361.6794
# Restoring model weights from the end of the best epoch
# Epoch 00006: early stopping

# %%
import os
from keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session


#model.load_weights('./new_logs/20210126-195623/model_multi_class/Best/weights_01_393.82.h5')



input_shape = (112, 112, 3)


output = model.predict(
    x=[Left_images[int(len(Left_images)*0.7):], Right_images[int(len(Left_images)*0.7):]],
    batch_size=16,
    verbose=1
)
# Out:
# 23796/23796 [==============================] - 76s 3ms/step

# %%
np.shape(output)
# Out:
# (13, 23796, 1)

# %%
th_0 = 0
th_1 = 0
th_2 = 0
th_3 = 0
th_4 = 0
th_5 = 0

percent_correct = []

k = 55524

for i  in range(np.shape(output)[1]):
    
    predicted_fov = 2*np.arctan(112/(2*output[0][i][0]))
    actual_fov = 2*np.arctan(112/(2*Fx[k]))
    
    if abs(predicted_fov - actual_fov) <= 0:
        
        th_0 += 1 
        
    if abs(predicted_fov - actual_fov) <= 1:
        
        th_1 += 1
        
    if abs(predicted_fov - actual_fov) <= 2:
        
        th_2 += 1
        
    if abs(predicted_fov - actual_fov) <= 3:
        
        th_3 += 1
        
    if abs(predicted_fov - actual_fov) <= 4:
        
        th_4 += 1
        
    if abs(predicted_fov - actual_fov) <= 5:
        
        th_5 += 1
        
    k += 1

percent_correct.append(th_0/np.shape(output)[1]*100)
percent_correct.append(th_1/np.shape(output)[1]*100)
percent_correct.append(th_2/np.shape(output)[1]*100)
percent_correct.append(th_3/np.shape(output)[1]*100)
percent_correct.append(th_4/np.shape(output)[1]*100)
percent_correct.append(th_5/np.shape(output)[1]*100)

plt.plot([0,1,2,3,4,5],percent_correct)
plt.xlabel("FOV Error Threshold (degrees)")
plt.ylabel("% Correct")
# Out:
# Text(0, 0.5, '% Correct')

# %%
th_0, th_1, th_2, th_3, th_4, th_5
# Out:
# (0, 22833, 23761, 23796, 23796, 23796)

# %%
th_0/np.shape(output)[1], th_1/np.shape(output)[1], th_2/np.shape(output)[1], th_3/np.shape(output)[1]
# Out:
# (0.0, 0.9595310136157338, 0.9985291645654731, 1.0)

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0



key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[1]):
        
        if key_counter == 0: 
    
            predicted_fx = output[key_counter][j][0]
            actual_fx = Fx[k]
    
            error[i] += abs(predicted_fx - actual_fx)
        
        if key_counter == 1: 
    
            predicted_fy = output[key_counter][j][0]
            actual_fy = Fy[k]
    
            error[i] += abs(predicted_fy - actual_fy)
        
        if key_counter == 2: 
    
            predicted_u0 = output[key_counter][j][0]
            actual_u0 = U0[k]
    
            error[i] += abs(predicted_u0 - actual_u0)
        
        if key_counter == 3: 
    
            predicted_v0 = output[key_counter][j][0]
            actual_v0 = V0[k]
    
            error[i] += abs(predicted_v0 - actual_v0)
        
        if key_counter == 4: 
    
            predicted_baseline = output[key_counter][j][0]
            actual_baseline = Baseline[k]
    
            error[i] += abs(predicted_baseline - actual_baseline)
        
        if key_counter == 5: 
    
            predicted_disparity = output[key_counter][j][0]
            actual_disparity = Disparity[k]
    
            error[i] += abs(predicted_disparity - actual_disparity)
        
        if key_counter == 6: 
    
            predicted_tx = output[key_counter][j][0]
            actual_tx = Tx[k]
    
            error[i] += abs(predicted_tx - actual_tx)
        
        if key_counter == 7: 
    
            predicted_ty = output[key_counter][j][0]
            actual_ty = Ty[k]
    
            error[i] += abs(predicted_ty - actual_ty)
        
        if key_counter == 8: 
    
            predicted_tz = output[key_counter][j][0]
            actual_tz = Tz[k]
    
            error[i] += abs(predicted_tz - actual_tz)
        
        if key_counter == 9: 
    
            predicted_pitch = output[key_counter][j][0]
            actual_pitch = Pitch[k]
    
            error[i] += abs(predicted_pitch - actual_pitch)
        
        if key_counter == 10: 
    
            predicted_x = output[key_counter][j][0]
            actual_x = X[k]
    
            error[i] += abs(predicted_x - actual_x)
        
        if key_counter == 11: 
    
            predicted_y = output[key_counter][j][0]
            actual_y = Y[k]
    
            error[i] += abs(predicted_y - actual_y)
        
        if key_counter == 12: 
    
            predicted_z = output[key_counter][j][0]
            actual_z = Z[k]
    
            error[i] += abs(predicted_z - actual_z)
        
        k += 1
    
    
    error[i] /= np.shape(output)[1]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 20.90661687351018, 'fy': 23.982494180860584, 'u0': 14.638445184098149, 'v0': 13.952649671343279, 'baseline': 1.0688530547260378, 'disparity': 1.3571549410861783, 'x': 0.8942286003650908, 'y': 1.010472244253217, 'z': 1.0152777246786457, 'pitch': 20.025231789572736, 'xworld': 5.847173687217292, 'yworld': 7.768674157410539, 'zworld': 10.666760955984012}

# %%
np.shape(output)
# Out:
# (13, 23796, 1)

# %%
k
# Out:
# 79320

# %%
sum(error.values())
# Out:
# 123.13403306510597
