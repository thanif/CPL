# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(1)
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.compat.v1.Session(config=config)
import matplotlib.pyplot as plt
import PIL.Image as Image
import math
import numpy as np
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
import json
from tensorflow.keras.losses import mse
import os
import glob
import random
#import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.inception_v3 import InceptionV3
import datetime
from tensorflow.keras.layers import Dense, Input, concatenate, Dropout, Conv2D, MaxPooling2D, Flatten, Lambda, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard
from scipy.special import softmax
# %matplotlib inline
# Out:
# WARNING:tensorflow:From /home/talha/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def euclidean_distance(y_true, y_pred):
    return K.sqrt(K.maximum(K.sum(K.square(y_pred - y_true), axis=-1, keepdims=True), K.epsilon()))

# %% [markdown]
# # Model

# %%
# feature extraction from input image
img = Input(shape = (112,112,2), name="input_image")

x = Conv2D(64, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv1")(img)
x = Conv2D(64, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv2")(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='pool1')(x)
    
x = Conv2D(64, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv3")(x)
x = Conv2D(64, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv4")(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='pool2')(x)
   
x = Conv2D(128, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv5")(x)
x = Conv2D(128, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv6")(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='pool3')(x)
    
x = Conv2D(128, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv7")(x)
x = Conv2D(128, (3, 3), padding="same", strides=(1, 1), activation="relu", name="conv8")(x)
x = BatchNormalization()(x)
    
x = Flatten()(x)
x = Dropout(0.75, noise_shape=None, seed=None)(x)
x = Dense(1024, name='FC1')(x)
out = Dense(13, name='loss')(x)

# create model
model = Model(inputs=[img], outputs=[out])

# set output types
target = tf.compat.v1.placeholder(dtype='float32', shape=(13,1)) 

# get model summary
model.summary()

# compile model
model.compile(optimizer=Adam(lr=0.0015, beta_1=0.9, beta_2=0.999, epsilon=1e-08), loss=euclidean_distance)
plot_model(model, to_file='model.png')
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 112, 112, 2)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 64)      1216
# _________________________________________________________________
# conv2 (Conv2D)               (None, 112, 112, 64)      36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 112, 112, 64)      256
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 56, 56, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 56, 56, 64)        36928
# _________________________________________________________________
# conv4 (Conv2D)               (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 56, 56, 64)        256
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 28, 28, 64)        0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 28, 28, 128)       73856
# _________________________________________________________________
# conv6 (Conv2D)               (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 14, 14, 128)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 14, 14, 128)       147584
# _________________________________________________________________
# conv8 (Conv2D)               (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# FC1 (Dense)                  (None, 1024)              25691136
# _________________________________________________________________
# loss (Dense)                 (None, 13)                13325
# =================================================================
# Total params: 26,334,605
# Trainable params: 26,333,837
# Non-trainable params: 768
# _________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
model.load_weights("./new_logs/20220116-141032/model_multi_class/Best/weights_09_15.56.h5")
# Out:
# 2022-01-22 17:51:14.657315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.657604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-01-22 17:51:14.657637: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-22 17:51:14.657661: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-01-22 17:51:14.657674: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-01-22 17:51:14.657686: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-01-22 17:51:14.657697: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-01-22 17:51:14.657709: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-01-22 17:51:14.657721: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-01-22 17:51:14.657772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.657980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.658153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-01-22 17:51:14.659217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.659699: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-01-22 17:51:14.659737: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-22 17:51:14.659796: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-01-22 17:51:14.659818: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-01-22 17:51:14.659839: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-01-22 17:51:14.659869: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-01-22 17:51:14.659906: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-01-22 17:51:14.659927: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-01-22 17:51:14.660026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.660297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.660525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-01-22 17:51:14.660574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-22 17:51:14.660587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-01-22 17:51:14.660596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-01-22 17:51:14.660718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.661089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-22 17:51:14.661429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2671 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)

# %% [markdown]
# # Get data

# %%
data_path = "../Data/"

Left_images = np.load(data_path+"li.npy")
Right_images = np.load(data_path+"ri.npy")
Fx = np.load(data_path+"fx.npy")
Fy = np.load(data_path+"fy.npy") 
U0 = np.load(data_path+"u0.npy") 
V0 = np.load(data_path+"v0.npy") 
Baseline = np.load(data_path+"b.npy")
Disparity = np.load(data_path+"d.npy") 
Tx = np.load(data_path+"tx.npy") 
Ty = np.load(data_path+"ty.npy") 
Tz = np.load(data_path+"tz.npy") 
Pitch = np.load(data_path+"p.npy")
Xw = np.load(data_path+"x.npy")
Yw = np.load(data_path+"y.npy") 
Zw = np.load(data_path+"z.npy")

# %%
X = []
Y = []

for idx in range(len(Left_images)):
                
    l_im = Left_images[idx]
    l_im = l_im[:,:,0]
    r_im = Right_images[idx]
    r_im = r_im[:,:,0]
    training_image = np.dstack((l_im, r_im))
        
    X.append(training_image)
                
    Y.append([Fx[idx], Fy[idx], U0[idx], V0[idx], Baseline[idx], Disparity[idx], Tx[idx], Ty[idx], Tz[idx], Pitch[idx], Xw[idx], Yw[idx], Zw[idx]])

# %%
print ("dataset: ",np.shape(X))
# Out:
# dataset:  (79320, 112, 112, 2)

# %%
print ("Training Dataset: ",len(X)*0.7, "Test Dataset: ", len(Y)*0.3)
# Out:
# Training Dataset:  55524.0 Test Dataset:  23796.0

# %%
import os
from tensorflow.keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

model_name = 'model_multi_class/'
SAVE = "new_logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '/'
# Save
output_folder = SAVE + model_name
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

output_log = output_folder + "Log/"
if not os.path.exists(output_log):
    os.makedirs(output_log)

output_weight = output_folder + "Best/"
if not os.path.exists(output_weight):
    os.makedirs(output_weight)


input_shape = (112, 112, 2)

tensorboard = TensorBoard(log_dir=output_log)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto', restore_best_weights=True)

csv_logger = CSVLogger('training.log')

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=output_weight + "weights_{epoch:02d}_{val_loss:.2f}.h5",
    monitor="val_loss",
    verbose=0,
    save_best_only=True,
    save_weights_only=True
)

history = model.fit(
    x=[X[:int(len(X)*0.7)]],
    y=[Y[:int(len(Y)*0.7)]],
    batch_size=16,
    epochs=200,
    verbose=1,
    shuffle=True,
    initial_epoch=0,
    validation_data=([X[int(len(X)*0.7):]], [Y[int(len(Y)*0.7):]]),
    callbacks=[tensorboard, checkpointer, early_stopping, csv_logger]
)
# Out:
# Using TensorFlow backend.
# Train on 55524 samples, validate on 23796 samples
# Epoch 1/200
# 2022-01-16 16:10:26.738385: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-01-16 16:11:05.395196: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
#    16/55524 [..............................] - ETA: 0s - loss: 16.2725
# 2022-01-16 16:12:01.738123: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session started.
# 2022-01-16 16:12:01.831283: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1391] Profiler found 1 GPUs
# 2022-01-16 16:12:03.432639: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcupti.so.10.1
# 2022-01-16 16:12:03.838821: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1441] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI_ERROR_INSUFFICIENT_PRIVILEGES
#    32/55524 [..............................] - ETA: 1:44:57 - loss: 21.4709WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.1758s vs `on_train_batch_begin` time: 2.1490s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1758s vs `on_train_batch_end` time: 1.3051s). Check your callbacks.
#    48/55524 [..............................] - ETA: 1:11:56 - loss: 21.8764
# 2022-01-16 16:12:04.017271: I tensorflow/core/profiler/internal/gpu/device_tracer.cc:223]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2022-01-16 16:12:04.713266: I tensorflow/core/profiler/rpc/client/save_profile.cc:176] Creating directory: new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04
# 2022-01-16 16:12:04.819792: I tensorflow/core/profiler/rpc/client/save_profile.cc:182] Dumped gzipped tool data for trace.json.gz to new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04/talha-Inspiron-15-7000-Gaming.trace.json.gz
# 2022-01-16 16:12:05.266501: I tensorflow/core/profiler/rpc/client/save_profile.cc:176] Creating directory: new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04
# 2022-01-16 16:12:05.270348: I tensorflow/core/profiler/rpc/client/save_profile.cc:182] Dumped gzipped tool data for memory_profile.json.gz to new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04/talha-Inspiron-15-7000-Gaming.memory_profile.json.gz
# 2022-01-16 16:12:05.317777: I tensorflow/python/profiler/internal/profiler_wrapper.cc:111] Creating directory: new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04Dumped tool data for xplane.pb to new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04/talha-Inspiron-15-7000-Gaming.xplane.pb
# Dumped tool data for overview_page.pb to new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04/talha-Inspiron-15-7000-Gaming.overview_page.pb
# Dumped tool data for input_pipeline.pb to new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04/talha-Inspiron-15-7000-Gaming.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04/talha-Inspiron-15-7000-Gaming.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to new_logs/20220116-161008/model_multi_class/Log/plugins/profile/2022_01_16_16_12_04/talha-Inspiron-15-7000-Gaming.kernel_stats.pb
# 55524/55524 [==============================] - ETA: 0s - loss: 19.5313WARNING:tensorflow:From /home/talha/anaconda3/envs/thesis-exp/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_v1.py:2044: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 55524/55524 [==============================] - 357s 6ms/sample - loss: 19.5313 - val_loss: 17.2795
# Epoch 2/200
# 55524/55524 [==============================] - 345s 6ms/sample - loss: 18.7882 - val_loss: 15.0530
# Epoch 3/200
# 55524/55524 [==============================] - 346s 6ms/sample - loss: 18.4088 - val_loss: 39.7908
# Epoch 4/200
# 55524/55524 [==============================] - 343s 6ms/sample - loss: 18.1141 - val_loss: 15.6653
# Epoch 5/200
# 55524/55524 [==============================] - 348s 6ms/sample - loss: 17.5173 - val_loss: 21.0108
# Epoch 6/200
# 55524/55524 [==============================] - 303s 5ms/sample - loss: 17.0491 - val_loss: 39.4262
# Epoch 7/200
# 55520/55524 [============================>.] - ETA: 0s - loss: 16.7393Restoring model weights from the end of the best epoch.
# 55524/55524 [==============================] - 297s 5ms/sample - loss: 16.7422 - val_loss: 24.8328
# Epoch 00007: early stopping

# %%
import os
from keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
#from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session


model.load_weights('./new_logs/20220116-161008/model_multi_class/Best/weights_02_15.05.h5')



input_shape = (112, 112, 2)


output = model.predict(
    x=[X[int(len(X)*0.7):]],
    batch_size=16,
    verbose=1
)
# Out:
# WARNING:tensorflow:From /home/talha/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.

# %%
np.save("../Data/p_dh_gd.npy", output)

# %%
np.shape(output)
# Out:
# (23796, 13)

# %%
th_0 = 0
th_1 = 0
th_2 = 0
th_3 = 0
th_4 = 0
th_5 = 0

percent_correct = []

k = 55524

for i  in range(np.shape(output)[0]):
    
    predicted_fov = 2*np.arctan(112/(2*output[i][0]))
    actual_fov = 2*np.arctan(112/(2*Y[k][0]))
    
    if abs(predicted_fov - actual_fov) <= 0:
        
        th_0 += 1 
        
    if abs(predicted_fov - actual_fov) <= 1:
        
        th_1 += 1
        
    if abs(predicted_fov - actual_fov) <= 2:
        
        th_2 += 1
        
    if abs(predicted_fov - actual_fov) <= 3:
        
        th_3 += 1
        
    if abs(predicted_fov - actual_fov) <= 4:
        
        th_4 += 1
        
    if abs(predicted_fov - actual_fov) <= 5:
        
        th_5 += 1
        
    k += 1

percent_correct.append(th_0/np.shape(output)[0]*100)
percent_correct.append(th_1/np.shape(output)[0]*100)
percent_correct.append(th_2/np.shape(output)[0]*100)
percent_correct.append(th_3/np.shape(output)[0]*100)
percent_correct.append(th_4/np.shape(output)[0]*100)
percent_correct.append(th_5/np.shape(output)[0]*100)

plt.plot([0,1,2,3,4,5],percent_correct)
plt.xlabel("FOV Error Threshold (degrees)")
plt.ylabel("% Correct")
# Out:
# Text(0, 0.5, '% Correct')

# %%
th_0, th_1, th_2, th_3, th_4, th_5
# Out:
# (0, 23789, 23796, 23796, 23796, 23796)

# %%
th_0/np.shape(output)[0], th_1/np.shape(output)[0], th_2/np.shape(output)[0], th_3/np.shape(output)[0]
# Out:
# (0.0, 0.9997058329130947, 1.0, 1.0)

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0



key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            predicted_fx = output[j][key_counter]
            actual_fx = Y[k][key_counter]
    
            error[i] += abs(predicted_fx - actual_fx)
        
        if key_counter == 1: 
    
            predicted_fy = output[j][key_counter]
            actual_fy = Y[k][key_counter]
    
            error[i] += abs(predicted_fy - actual_fy)
        
        if key_counter == 2: 
    
            predicted_u0 = output[j][key_counter]
            actual_u0 = Y[k][key_counter]
    
            error[i] += abs(predicted_u0 - actual_u0)
        
        if key_counter == 3: 
    
            predicted_v0 = output[j][key_counter]
            actual_v0 = Y[k][key_counter]
    
            error[i] += abs(predicted_v0 - actual_v0)
        
        if key_counter == 4: 
    
            predicted_baseline = output[j][key_counter]
            actual_baseline = Y[k][key_counter]
    
            error[i] += abs(predicted_baseline - actual_baseline)
        
        if key_counter == 5: 
    
            predicted_disparity = output[j][key_counter]
            actual_disparity = Y[k][key_counter]
    
            error[i] += abs(predicted_disparity - actual_disparity)
        
        if key_counter == 6: 
    
            predicted_tx = output[j][key_counter]
            actual_tx = Y[k][key_counter]
    
            error[i] += abs(predicted_tx - actual_tx)
        
        if key_counter == 7: 
    
            predicted_ty = output[j][key_counter]
            actual_ty = Y[k][key_counter]
    
            error[i] += abs(predicted_ty - actual_ty)
        
        if key_counter == 8: 
    
            predicted_tz = output[j][key_counter]
            actual_tz = Y[k][key_counter]
    
            error[i] += abs(predicted_tz - actual_tz)
        
        if key_counter == 9: 
    
            predicted_pitch = output[j][key_counter]
            actual_pitch = Y[k][key_counter]
    
            error[i] += abs(predicted_pitch - actual_pitch)
        
        if key_counter == 10: 
    
            predicted_x = output[j][key_counter]
            actual_x = Y[k][key_counter]
    
            error[i] += abs(predicted_x - actual_x)
        
        if key_counter == 11: 
    
            predicted_y = output[j][key_counter]
            actual_y = Y[k][key_counter]
    
            error[i] += abs(predicted_y - actual_y)
        
        if key_counter == 12: 
    
            predicted_z = output[j][key_counter]
            actual_z = Y[k][key_counter]
    
            error[i] += abs(predicted_z - actual_z)
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 5.265938721249232, 'fy': 5.266425137784103, 'u0': 0.45904574247543944, 'v0': 0.45952033034731987, 'baseline': 0.4912319698816068, 'disparity': 0.36981838445333926, 'x': 0.491493830727537, 'y': 0.5311968841859724, 'z': 0.44608661392633203, 'pitch': 3.8081651023304306, 'xworld': 5.918440233646864, 'yworld': 2.6357550457041046, 'zworld': 6.8456484798649555}

# %% [markdown]
# # Normalization

# %%
import math 

def normalize(x):
    
    return (math.atan(x) + 3.14/2) / 3.14

# %%
normalize(0.1)
# Out:
# 0.5317416090736184

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0



key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            predicted_fx = output[j][key_counter]
            actual_fx = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_fx - actual_fx))
        
        if key_counter == 1: 
    
            predicted_fy = output[j][key_counter]
            actual_fy = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_fy - actual_fy))
        
        if key_counter == 2: 
    
            predicted_u0 = output[j][key_counter]
            actual_u0 = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_u0 - actual_u0))
        
        if key_counter == 3: 
    
            predicted_v0 = output[j][key_counter]
            actual_v0 = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_v0 - actual_v0))
        
        if key_counter == 4: 
    
            predicted_baseline = output[j][key_counter]
            actual_baseline = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_baseline - actual_baseline))
        
        if key_counter == 5: 
    
            predicted_disparity = output[j][key_counter]
            actual_disparity = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_disparity - actual_disparity))
        
        if key_counter == 6: 
    
            predicted_tx = output[j][key_counter]
            actual_tx = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_tx - actual_tx))
        
        if key_counter == 7: 
    
            predicted_ty = output[j][key_counter]
            actual_ty = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_ty - actual_ty))
        
        if key_counter == 8: 
    
            predicted_tz = output[j][key_counter]
            actual_tz = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_tz - actual_tz))
        
        if key_counter == 9: 
    
            predicted_pitch = output[j][key_counter]
            actual_pitch = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_pitch - actual_pitch))
        
        if key_counter == 10: 
    
            predicted_x = output[j][key_counter]
            actual_x = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_x - actual_x))
        
        if key_counter == 11: 
    
            predicted_y = output[j][key_counter]
            actual_y = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_y - actual_y))
        
        if key_counter == 12: 
    
            predicted_z = output[j][key_counter]
            actual_z = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_z - actual_z))
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 0.8512709279363962, 'fy': 0.8512272692398725, 'u0': 0.6245586283144898, 'v0': 0.6247780335936864, 'baseline': 0.6281046082403036, 'disparity': 0.601158918387572, 'x': 0.6282740506494657, 'y': 0.6366087300863801, 'z': 0.6225423970807069, 'pitch': 0.847056230169479, 'xworld': 0.8541311359623682, 'yworld': 0.7930498640321066, 'zworld': 0.8656656240467197}

# %% [markdown]
# # Range Normalization

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0


min_fx = 1.9073486e-06
max_fx = 3214.9907

min_fy = 2.9563904e-05
max_fy = 2051.209

min_u0 = 1.9073486e-05
max_u0 = 2178.9983

min_v0 = 3.8146973e-06
max_v0 = 2385.7239

min_baseline = 4.7683716e-06
max_baseline = 22.68721567997021

min_disparity = 9.536743e-07
max_disparity = 134.60031

min_tx = 2.384185791015625e-06
max_tx = 22.68721567997021

min_ty = 2.3841858e-07
max_ty = 33.11693576309983

min_tz = 2.3841858e-06
max_tz = 17.20185265614626

min_pitch = 4.57763671875e-05
max_pitch = 4502.9224

min_xw = 5.219264654243716e-06
max_xw = 386.4486

min_yw = 3.8146973e-06
max_yw = 1835.1849

min_zw = 0.00011349
max_zw = 339.17166



key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            predicted_fx = output[j][key_counter]
            actual_fx = Y[k][key_counter]
    
            error[i] += (abs(predicted_fx - actual_fx) - min_fx)/(max_fx - min_fx)
        
        if key_counter == 1: 
    
            predicted_fy = output[j][key_counter]
            actual_fy = Y[k][key_counter]
    
            error[i] += (abs(predicted_fy - actual_fy) - min_fy)/(max_fy - min_fy)
        
        if key_counter == 2: 
    
            predicted_u0 = output[j][key_counter]
            actual_u0 = Y[k][key_counter]
    
            error[i] += (abs(predicted_u0 - actual_u0) - min_u0)/(max_u0 - min_u0)
        
        if key_counter == 3: 
    
            predicted_v0 = output[j][key_counter]
            actual_v0 = Y[k][key_counter]
    
            error[i] += (abs(predicted_v0 - actual_v0) - min_v0)/(max_v0 - min_v0)
        
        if key_counter == 4: 
    
            predicted_baseline = output[j][key_counter]
            actual_baseline = Y[k][key_counter]
    
            error[i] += (abs(predicted_baseline - actual_baseline) - min_baseline)/(max_baseline - min_baseline)
        
        if key_counter == 5: 
    
            predicted_disparity = output[j][key_counter]
            actual_disparity = Y[k][key_counter]
    
            error[i] += (abs(predicted_disparity - actual_disparity) - min_disparity)/(max_disparity - min_disparity)
        
        if key_counter == 6: 
    
            predicted_tx = output[j][key_counter]
            actual_tx = Y[k][key_counter]
    
            error[i] += (abs(predicted_tx - actual_tx) - min_tx)/(max_tx - min_tx)
        
        if key_counter == 7: 
    
            predicted_ty = output[j][key_counter]
            actual_ty = Y[k][key_counter]
    
            error[i] += (abs(predicted_ty - actual_ty) - min_ty)/(max_ty - min_ty)
        
        if key_counter == 8: 
    
            predicted_tz = output[j][key_counter]
            actual_tz = Y[k][key_counter]
    
            error[i] += (abs(predicted_tz - actual_tz) - min_tz)/(max_tz - min_tz)
        
        if key_counter == 9: 
    
            predicted_pitch = output[j][key_counter]
            actual_pitch = Y[k][key_counter]
    
            error[i] += (abs(predicted_pitch - actual_pitch) - min_pitch)/(max_pitch - min_pitch)
        
        if key_counter == 10: 
    
            predicted_x = output[j][key_counter]
            actual_x = Y[k][key_counter]
    
            error[i] += (abs(predicted_x - actual_x) - min_xw)/(max_xw - min_xw)
        
        if key_counter == 11: 
    
            predicted_y = output[j][key_counter]
            actual_y = Y[k][key_counter]
    
            error[i] += (abs(predicted_y - actual_y) - min_yw)/(max_yw - min_yw)
        
        if key_counter == 12: 
    
            predicted_z = output[j][key_counter]
            actual_z = Y[k][key_counter]
    
            error[i] += (abs(predicted_z - actual_z) - min_zw)/(max_zw - min_zw)
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 0.0016379307159600902, 'fy': 0.002567456943849802, 'u0': 0.0002106594151124075, 'v0': 0.0001926108599700836, 'baseline': 0.021652145111459225, 'disparity': 0.0027475231109437078, 'x': 0.021663789707862008, 'y': 0.016040024200977974, 'z': 0.025932329475609982, 'pitch': 0.0008456991990169412, 'xworld': 0.015314927697806135, 'yworld': 0.001436232050462973, 'zworld': 0.02018307642376247}

# %% [markdown]
# # Normalized MAE

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0


mean_fx = 84.70939817976283

mean_fy = 84.70939817976283

mean_u0 = 56.0

mean_v0 = 56.0

mean_baseline = 3.1362834089762988

mean_disparity = 5.6359135359419765

mean_tx = 3.1362834089762988

mean_ty = 3.2890401748192972

mean_tz = 2.8612371827197847

mean_pitch = 84.54614220877458

mean_xw = 31.613377053172897

mean_yw = 25.092866140117593

mean_zw = 42.71013880363322



key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            predicted_fx = output[j][key_counter]
            actual_fx = Y[k][key_counter]
    
            error[i] += abs(predicted_fx - actual_fx) / mean_fx
        
        if key_counter == 1: 
    
            predicted_fy = output[j][key_counter]
            actual_fy = Y[k][key_counter]
    
            error[i] += abs(predicted_fy - actual_fy) / mean_fy
        
        if key_counter == 2: 
    
            predicted_u0 = output[j][key_counter]
            actual_u0 = Y[k][key_counter]
    
            error[i] += abs(predicted_u0 - actual_u0) / mean_u0
        
        if key_counter == 3: 
    
            predicted_v0 = output[j][key_counter]
            actual_v0 = Y[k][key_counter]
    
            error[i] += abs(predicted_v0 - actual_v0) / mean_v0
        
        if key_counter == 4: 
    
            predicted_baseline = output[j][key_counter]
            actual_baseline = Y[k][key_counter]
    
            error[i] += abs(predicted_baseline - actual_baseline) / mean_baseline
        
        if key_counter == 5: 
    
            predicted_disparity = output[j][key_counter]
            actual_disparity = Y[k][key_counter]
    
            error[i] += abs(predicted_disparity - actual_disparity) / mean_disparity
        
        if key_counter == 6: 
    
            predicted_tx = output[j][key_counter]
            actual_tx = Y[k][key_counter]
    
            error[i] += abs(predicted_tx - actual_tx) / mean_tx
        
        if key_counter == 7: 
    
            predicted_ty = output[j][key_counter]
            actual_ty = Y[k][key_counter]
    
            error[i] += abs(predicted_ty - actual_ty) / mean_ty
        
        if key_counter == 8: 
    
            predicted_tz = output[j][key_counter]
            actual_tz = Y[k][key_counter]
    
            error[i] += abs(predicted_tz - actual_tz) / mean_tz
        
        if key_counter == 9: 
    
            predicted_pitch = output[j][key_counter]
            actual_pitch = Y[k][key_counter]
    
            error[i] += abs(predicted_pitch - actual_pitch) / mean_pitch
        
        if key_counter == 10: 
    
            predicted_x = output[j][key_counter]
            actual_x = Y[k][key_counter]
    
            error[i] += abs(predicted_x - actual_x) / mean_xw
        
        if key_counter == 11: 
    
            predicted_y = output[j][key_counter]
            actual_y = Y[k][key_counter]
    
            error[i] += abs(predicted_y - actual_y) / mean_yw
        
        if key_counter == 12: 
    
            predicted_z = output[j][key_counter]
            actual_z = Y[k][key_counter]
    
            error[i] += abs(predicted_z - actual_z) / mean_zw
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 0.06216469525737462, 'fy': 0.06217043671070798, 'u0': 0.008197242444230772, 'v0': 0.008205716892727201, 'baseline': 0.1566285590766034, 'disparity': 0.06561818437433378, 'x': 0.1567120498984182, 'y': 0.16150507669790887, 'z': 0.15590683489033644, 'pitch': 0.045042428963416266, 'xworld': 0.18721307430382195, 'yworld': 0.10504002079340902, 'zworld': 0.16028135065191315}

# %%
softmax(0.1)
# Out:
# 1.0

# %%
k
# Out:
# 79320

# %%
sum(error.values())
# Out:
# 163.44208461933255

# %% [markdown]
# # Average

# %% [markdown]
# # Normalization

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0

predicted_fx = np.average(Y[:int(len(Y)*0.7)][0])
predicted_fy = np.average(Y[:int(len(Y)*0.7)][1])
predicted_u0 = np.average(Y[:int(len(Y)*0.7)][2])
predicted_v0 = np.average(Y[:int(len(Y)*0.7)][3])
predicted_baseline = np.average(Y[:int(len(Y)*0.7)][4])
predicted_disparity = np.average(Y[:int(len(Y)*0.7)][5])
predicted_tx = np.average(Y[:int(len(Y)*0.7)][6])
predicted_ty = np.average(Y[:int(len(Y)*0.7)][7])
predicted_tz = np.average(Y[:int(len(Y)*0.7)][8])
predicted_pitch = np.average(Y[:int(len(Y)*0.7)][9])
predicted_x = np.average(Y[:int(len(Y)*0.7)][10])
predicted_y = np.average(Y[:int(len(Y)*0.7)][11])
predicted_z = np.average(Y[:int(len(Y)*0.7)][12])

key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            
            actual_fx = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_fx - actual_fx))
        
        if key_counter == 1: 
    
            
            actual_fy = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_fy - actual_fy))
        
        if key_counter == 2: 
    
            
            actual_u0 = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_u0 - actual_u0))
        
        if key_counter == 3: 
    
            
            actual_v0 = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_v0 - actual_v0))
        
        if key_counter == 4: 
    
            
            actual_baseline = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_baseline - actual_baseline))
        
        if key_counter == 5: 
    
            
            actual_disparity = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_disparity - actual_disparity))
        
        if key_counter == 6: 
    
            
            actual_tx = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_tx - actual_tx))
        
        if key_counter == 7: 
    
            
            actual_ty = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_ty - actual_ty))
        
        if key_counter == 8: 
    
            
            actual_tz = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_tz - actual_tz))
        
        if key_counter == 9: 
    
            
            actual_pitch = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_pitch - actual_pitch))
        
        if key_counter == 10: 
    
            
            actual_x = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_x - actual_x))
        
        if key_counter == 11: 
    
            
            actual_y = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_y - actual_y))
        
        if key_counter == 12: 
    
            
            actual_z = Y[k][key_counter]
    
            error[i] += normalize(abs(predicted_z - actual_z))
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 0.9638290425859471, 'fy': 0.9793228977471565, 'u0': 0.9871012419981784, 'v0': 0.9897671163477518, 'baseline': 0.9847074597723048, 'disparity': 0.9846013309331616, 'x': 0.9847074597723048, 'y': 0.9899055308256802, 'z': 0.9793726992170018, 'pitch': 0.986439566958112, 'xworld': 0.9701594907878228, 'yworld': 0.9909902306686719, 'zworld': 0.994382882756602}

# %% [markdown]
# # Range Normalization

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0

min_fx = 1.9073486e-06
max_fx = 3214.9907

min_fy = 2.9563904e-05
max_fy = 2051.209

min_u0 = 1.9073486e-05
max_u0 = 2178.9983

min_v0 = 3.8146973e-06
max_v0 = 2385.7239

min_baseline = 4.7683716e-06
max_baseline = 22.68721567997021

min_disparity = 9.536743e-07
max_disparity = 134.60031

min_tx = 2.384185791015625e-06
max_tx = 22.68721567997021

min_ty = 2.3841858e-07
max_ty = 33.11693576309983

min_tz = 2.3841858e-06
max_tz = 17.20185265614626

min_pitch = 4.57763671875e-05
max_pitch = 4502.9224

min_xw = 5.219264654243716e-06
max_xw = 386.4486

min_yw = 3.8146973e-06
max_yw = 1835.1849

min_zw = 0.00011349
max_zw = 339.17166


predicted_fx = np.average(Y[:int(len(Y)*0.7)][0])
predicted_fy = np.average(Y[:int(len(Y)*0.7)][1])
predicted_u0 = np.average(Y[:int(len(Y)*0.7)][2])
predicted_v0 = np.average(Y[:int(len(Y)*0.7)][3])
predicted_baseline = np.average(Y[:int(len(Y)*0.7)][4])
predicted_disparity = np.average(Y[:int(len(Y)*0.7)][5])
predicted_tx = np.average(Y[:int(len(Y)*0.7)][6])
predicted_ty = np.average(Y[:int(len(Y)*0.7)][7])
predicted_tz = np.average(Y[:int(len(Y)*0.7)][8])
predicted_pitch = np.average(Y[:int(len(Y)*0.7)][9])
predicted_x = np.average(Y[:int(len(Y)*0.7)][10])
predicted_y = np.average(Y[:int(len(Y)*0.7)][11])
predicted_z = np.average(Y[:int(len(Y)*0.7)][12])

key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            
            actual_fx = Y[k][key_counter]
    
            error[i] += (abs(predicted_fx - actual_fx) - min_fx)/(max_fx - min_fx)
        
        if key_counter == 1: 
    
            
            actual_fy = Y[k][key_counter]
    
            error[i] += (abs(predicted_fy - actual_fy) - min_fy)/(max_fy - min_fy)
        
        if key_counter == 2: 
    
            
            actual_u0 = Y[k][key_counter]
    
            error[i] += (abs(predicted_u0 - actual_u0) - min_u0)/(max_u0 - min_u0)
        
        if key_counter == 3: 
    
            
            actual_v0 = Y[k][key_counter]
    
            error[i] += (abs(predicted_v0 - actual_v0) - min_v0)/(max_v0 - min_v0)
        
        if key_counter == 4: 
    
            
            actual_baseline = Y[k][key_counter]
    
            error[i] += (abs(predicted_baseline - actual_baseline) - min_baseline)/(max_baseline - min_baseline)
        
        if key_counter == 5: 
    
            
            actual_disparity = Y[k][key_counter]
    
            error[i] += (abs(predicted_disparity - actual_disparity) - min_disparity)/(max_disparity - min_disparity)
        
        if key_counter == 6: 
    
            
            actual_tx = Y[k][key_counter]
    
            error[i] += (abs(predicted_tx - actual_tx) - min_tx)/(max_tx - min_tx)
        
        if key_counter == 7: 
    
            
            actual_ty = Y[k][key_counter]
    
            error[i] += (abs(predicted_ty - actual_ty) - min_ty)/(max_ty - min_ty)
        
        if key_counter == 8: 
    
            
            actual_tz = Y[k][key_counter]
    
            error[i] += (abs(predicted_tz - actual_tz) - min_tz)/(max_tz - min_tz)
        
        if key_counter == 9: 
    
            
            actual_pitch = Y[k][key_counter]
    
            error[i] += (abs(predicted_pitch - actual_pitch) - min_pitch)/(max_pitch - min_pitch)
        
        if key_counter == 10: 
    
            
            actual_x = Y[k][key_counter]
    
            error[i] += (abs(predicted_x - actual_x) - min_xw)/(max_xw - min_xw)
        
        if key_counter == 11: 
    
            
            actual_y = Y[k][key_counter]
    
            error[i] += (abs(predicted_y - actual_y) - min_yw)/(max_yw - min_yw)
        
        if key_counter == 12: 
    
            
            actual_z = Y[k][key_counter]
    
            error[i] += (abs(predicted_z - actual_z) - min_zw)/(max_zw - min_zw)
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 0.02215451394924558, 'fy': 0.03248553507416783, 'u0': 0.011106117329517086, 'v0': 0.012725150706368243, 'baseline': 0.9058375479778504, 'disparity': 0.1510505030387321, 'x': 0.9058375578735164, 'y': 0.9308800727312996, 'z': 0.8918001753710884, 'pitch': 0.013971151153016729, 'xworld': 0.10897030923222067, 'yworld': 0.020870388162276914, 'zworld': 0.23669055298470795}

# %% [markdown]
# # Normalized MAE

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0

mean_fx = 84.70939817976283

mean_fy = 84.70939817976283

mean_u0 = 56.0

mean_v0 = 56.0

mean_baseline = 3.1362834089762988

mean_disparity = 5.6359135359419765

mean_tx = 3.1362834089762988

mean_ty = 3.2890401748192972

mean_tz = 2.8612371827197847

mean_pitch = 84.54614220877458

mean_xw = 31.613377053172897

mean_yw = 25.092866140117593

mean_zw = 42.71013880363322


predicted_fx = np.average(Y[:int(len(Y)*0.7)][0])
predicted_fy = np.average(Y[:int(len(Y)*0.7)][1])
predicted_u0 = np.average(Y[:int(len(Y)*0.7)][2])
predicted_v0 = np.average(Y[:int(len(Y)*0.7)][3])
predicted_baseline = np.average(Y[:int(len(Y)*0.7)][4])
predicted_disparity = np.average(Y[:int(len(Y)*0.7)][5])
predicted_tx = np.average(Y[:int(len(Y)*0.7)][6])
predicted_ty = np.average(Y[:int(len(Y)*0.7)][7])
predicted_tz = np.average(Y[:int(len(Y)*0.7)][8])
predicted_pitch = np.average(Y[:int(len(Y)*0.7)][9])
predicted_x = np.average(Y[:int(len(Y)*0.7)][10])
predicted_y = np.average(Y[:int(len(Y)*0.7)][11])
predicted_z = np.average(Y[:int(len(Y)*0.7)][12])

key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            
            actual_fx = Y[k][key_counter]
    
            error[i] += abs(predicted_fx - actual_fx) / mean_fx
        
        if key_counter == 1: 
    
            
            actual_fy = Y[k][key_counter]
    
            error[i] += abs(predicted_fy - actual_fy) / mean_fy
        
        if key_counter == 2: 
    
            
            actual_u0 = Y[k][key_counter]
    
            error[i] += abs(predicted_u0 - actual_u0) / mean_u0
        
        if key_counter == 3: 
    
            
            actual_v0 = Y[k][key_counter]
    
            error[i] += abs(predicted_v0 - actual_v0) / mean_v0
        
        if key_counter == 4: 
    
            
            actual_baseline = Y[k][key_counter]
    
            error[i] += abs(predicted_baseline - actual_baseline) / mean_baseline
        
        if key_counter == 5: 
    
            
            actual_disparity = Y[k][key_counter]
    
            error[i] += abs(predicted_disparity - actual_disparity) / mean_disparity
        
        if key_counter == 6: 
    
            
            actual_tx = Y[k][key_counter]
    
            error[i] += abs(predicted_tx - actual_tx) / mean_tx
        
        if key_counter == 7: 
    
            
            actual_ty = Y[k][key_counter]
    
            error[i] += abs(predicted_ty - actual_ty) / mean_ty
        
        if key_counter == 8: 
    
            
            actual_tz = Y[k][key_counter]
    
            error[i] += abs(predicted_tz - actual_tz) / mean_tz
        
        if key_counter == 9: 
    
            
            actual_pitch = Y[k][key_counter]
    
            error[i] += abs(predicted_pitch - actual_pitch) / mean_pitch
        
        if key_counter == 10: 
    
            
            actual_x = Y[k][key_counter]
    
            error[i] += abs(predicted_x - actual_x) / mean_xw
        
        if key_counter == 11: 
    
            
            actual_y = Y[k][key_counter]
    
            error[i] += abs(predicted_y - actual_y) / mean_yw
        
        if key_counter == 12: 
    
            
            actual_z = Y[k][key_counter]
    
            error[i] += abs(predicted_z - actual_z) / mean_zw
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)

# %%
 np.shape(output)[0]
# Out:
# 23796

# %%
predicted_fx = np.average(Y[int(len(Y)*0.7):][0])
predicted_fy = np.average(Y[int(len(Y)*0.7):][1])

predicted_fx, predicted_fy
# Out:
# (15.822783046241339, 15.721366347658554)

# %%
actual_fx
# Out:
# 96.99484522385714

# %%
predicted_fx = np.average(Y[:int(len(Y)*0.7)][0])
predicted_fy = np.average(Y[:int(len(Y)*0.7)][1])
predicted_u0 = np.average(Y[:int(len(Y)*0.7)][2])
predicted_v0 = np.average(Y[:int(len(Y)*0.7)][3])
predicted_baseline = np.average(Y[:int(len(Y)*0.7)][4])
predicted_disparity = np.average(Y[:int(len(Y)*0.7)][5])
predicted_tx = np.average(Y[:int(len(Y)*0.7)][6])
predicted_ty = np.average(Y[:int(len(Y)*0.7)][7])
predicted_tz = np.average(Y[:int(len(Y)*0.7)][8])
predicted_pitch = np.average(Y[:int(len(Y)*0.7)][9])
predicted_x = np.average(Y[:int(len(Y)*0.7)][10])
predicted_y = np.average(Y[:int(len(Y)*0.7)][11])
predicted_z = np.average(Y[:int(len(Y)*0.7)][12])

# %%
output = [predicted_fx, predicted_fy, predicted_u0, predicted_v0, predicted_baseline, predicted_disparity, predicted_tx, predicted_ty, predicted_tz, predicted_pitch, predicted_x, predicted_y, predicted_z]
np.save("../Data/p_avg_gd.npy", output)

# %% [markdown]
# # Average

# %%
error = {}

error["fx"] = 0
error["fy"] = 0
error["u0"] = 0
error["v0"] = 0
error["baseline"] = 0
error["disparity"] = 0
error["x"] = 0
error["y"] = 0
error["z"] = 0
error["pitch"] = 0
error["xworld"] = 0
error["yworld"] = 0
error["zworld"] = 0

predicted_fx = np.average(Y[:int(len(Y)*0.7)][0])
predicted_fy = np.average(Y[:int(len(Y)*0.7)][1])
predicted_u0 = np.average(Y[:int(len(Y)*0.7)][2])
predicted_v0 = np.average(Y[:int(len(Y)*0.7)][3])
predicted_baseline = np.average(Y[:int(len(Y)*0.7)][4])
predicted_disparity = np.average(Y[:int(len(Y)*0.7)][5])
predicted_tx = np.average(Y[:int(len(Y)*0.7)][6])
predicted_ty = np.average(Y[:int(len(Y)*0.7)][7])
predicted_tz = np.average(Y[:int(len(Y)*0.7)][8])
predicted_pitch = np.average(Y[:int(len(Y)*0.7)][9])
predicted_x = np.average(Y[:int(len(Y)*0.7)][10])
predicted_y = np.average(Y[:int(len(Y)*0.7)][11])
predicted_z = np.average(Y[:int(len(Y)*0.7)][12])

key_counter = 0

for i in error.keys():
    
    k = 55524

    for j  in range(np.shape(output)[0]):
        
        if key_counter == 0: 
    
            
            actual_fx = Y[k][key_counter]
    
            error[i] += abs(predicted_fx - actual_fx)
        
        if key_counter == 1: 
    
            
            actual_fy = Y[k][key_counter]
    
            error[i] += abs(predicted_fy - actual_fy)
        
        if key_counter == 2: 
    
            
            actual_u0 = Y[k][key_counter]
    
            error[i] += abs(predicted_u0 - actual_u0)
        
        if key_counter == 3: 
    
            
            actual_v0 = Y[k][key_counter]
    
            error[i] += abs(predicted_v0 - actual_v0)
        
        if key_counter == 4: 
    
            
            actual_baseline = Y[k][key_counter]
    
            error[i] += abs(predicted_baseline - actual_baseline)
        
        if key_counter == 5: 
    
            
            actual_disparity = Y[k][key_counter]
    
            error[i] += abs(predicted_disparity - actual_disparity)
        
        if key_counter == 6: 
    
            
            actual_tx = Y[k][key_counter]
    
            error[i] += abs(predicted_tx - actual_tx)
        
        if key_counter == 7: 
    
            
            actual_ty = Y[k][key_counter]
    
            error[i] += abs(predicted_ty - actual_ty)
        
        if key_counter == 8: 
    
            
            actual_tz = Y[k][key_counter]
    
            error[i] += abs(predicted_tz - actual_tz)
        
        if key_counter == 9: 
    
            
            actual_pitch = Y[k][key_counter]
    
            error[i] += abs(predicted_pitch - actual_pitch)
        
        if key_counter == 10: 
    
            
            actual_x = Y[k][key_counter]
    
            error[i] += abs(predicted_x - actual_x)
        
        if key_counter == 11: 
    
            
            actual_y = Y[k][key_counter]
    
            error[i] += abs(predicted_y - actual_y)
        
        if key_counter == 12: 
    
            
            actual_z = Y[k][key_counter]
    
            error[i] += abs(predicted_z - actual_z)
        
        k += 1
    
    
    error[i] /= np.shape(output)[0]
    
    key_counter += 1

print (error)
# Out:
# {'fx': 71.2265581749228, 'fy': 66.63465051744465, 'u0': 24.200229642266457, 'v0': 30.35869993745694, 'baseline': 20.55093227098993, 'disparity': 20.331445344304647, 'x': 20.55093227098993, 'y': 30.827895588264717, 'z': 15.340615473424648, 'pitch': 62.91105461756268, 'xworld': 42.11142809487513, 'yworld': 38.30102494763889, 'zworld': 80.27881439013812}

# %%
# In[ ]:


avg_fov_train = 0


k = 0


for i  in range(len(Y[:int(len(Y)*0.7)])):
    
    avg_fov_train += 2*np.arctan(112/(2*Y[i][0]))
    
    k += 1


avg_fov_train /= len(Y[:int(len(Y)*0.7)])

print ("avg. fov train: ",avg_fov_train)


# In[ ]:


th_0 = 0
th_1 = 0
th_2 = 0
th_3 = 0
th_4 = 0
th_5 = 0

percent_correct = []

for i  in range(len(Y[int(len(Y)*0.7):])):
    
    predicted_fov = avg_fov_train
    actual_fov = 2*np.arctan(112/(2*Y[k][0]))
    
    if abs(predicted_fov - actual_fov) <= 0:
        
        th_0 += 1 
        
    if abs(predicted_fov - actual_fov) <= 1:
        
        th_1 += 1
        
    if abs(predicted_fov - actual_fov) <= 2:
        
        th_2 += 1
        
    if abs(predicted_fov - actual_fov) <= 3:
        
        th_3 += 1
        
    if abs(predicted_fov - actual_fov) <= 4:
        
        th_4 += 1
        
    if abs(predicted_fov - actual_fov) <= 5:
        
        th_5 += 1

    k += 1

percent_correct.append(th_0/len(Y[int(len(Y)*0.7):])*100)
percent_correct.append(th_1/len(Y[int(len(Y)*0.7):])*100)
percent_correct.append(th_2/len(Y[int(len(Y)*0.7):])*100)
percent_correct.append(th_3/len(Y[int(len(Y)*0.7):])*100)
percent_correct.append(th_4/len(Y[int(len(Y)*0.7):])*100)
percent_correct.append(th_5/len(Y[int(len(Y)*0.7):])*100)



# In[ ]:


#th_0, th_1, th_2, th_3, th_4, th_5


# In[ ]:


print (th_0/len(Y[int(len(Y)*0.7):]), th_1/len(Y[int(len(Y)*0.7):]), th_2/len(Y[int(len(Y)*0.7):]), th_3/len(Y[int(len(Y)*0.7):]), th_4/len(Y[int(len(Y)*0.7):]), th_5/len(Y[int(len(Y)*0.7):]))
# Out:
# avg. fov train:  1.5695232586675751
# 0.0 0.6084636073289629 1.0 1.0 1.0 1.0

# %%
th_0 = 0
th_1 = 0
th_2 = 0
th_3 = 0
th_4 = 0
th_5 = 0

percent_correct = []

k = 55524

for i  in range(23796):
    
    predicted_fov = 2*np.arctan(112/(2*predicted_fx))
    actual_fov = 2*np.arctan(112/(2*Y[k][0]))
    
    if abs(predicted_fov - actual_fov) <= 0:
        
        th_0 += 1 
        
    if abs(predicted_fov - actual_fov) <= 1:
        
        th_1 += 1
        
    if abs(predicted_fov - actual_fov) <= 2:
        
        th_2 += 1
        
    if abs(predicted_fov - actual_fov) <= 3:
        
        th_3 += 1
        
    if abs(predicted_fov - actual_fov) <= 4:
        
        th_4 += 1
        
    if abs(predicted_fov - actual_fov) <= 5:
        
        th_5 += 1
        
    k += 1

percent_correct.append(th_0/23796*100)
percent_correct.append(th_1/23796*100)
percent_correct.append(th_2/23796*100)
percent_correct.append(th_3/23796*100)
percent_correct.append(th_4/23796*100)
percent_correct.append(th_5/23796*100)

plt.plot([0,1,2,3,4,5],percent_correct)
plt.xlabel("FOV Error Threshold (degrees)")
plt.ylabel("% Correct")
# Out:
# Text(0, 0.5, '% Correct')

# %%
th_0, th_1, th_2, th_3, th_4, th_5
# Out:
# (0, 11131, 18230, 23796, 23796, 23796)

# %%
th_0/23796, th_1/23796, th_2/23796, th_3/23796
# Out:
# (0.0, 0.46776769204908386, 0.7660951420406791, 1.0)
